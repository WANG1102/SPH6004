# %%
import torch
from torch import nn
from torch.autograd import Variable
import torchvision.datasets as dsets
import torchvision.transforms as transforms
import torch.utils.data as Data
import matplotlib.pyplot as plt

# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=3
torch.set_num_threads(2)

# %%
import os.path as osp
from PIL import Image
import numpy as np
from torch.utils.data import Dataset
from torchvision import transforms


ROOT_PATH = '/home/jiahao/code/SPH6004/mimiciv_aki/'


class ISIC(Dataset):

    def __init__(self, setname):
        csv_path = osp.join(ROOT_PATH, setname + '.npy')
        data = np.load(csv_path)
        
        self.data = data[:,0]
        label = data[:,1]
        label_tensor = torch.from_numpy(label.astype(float))
        self.label = label_tensor.tolist()
#         self.label = torch.from_numpy(label.astype(float))
            
    def __len__(self):
        return len(self.data)

    def __getitem__(self, i):
        data, label = self.data[i], self.label[i]
        data_tensor = torch.tensor(data)
        label = torch.tensor(label)
        return data_tensor, label

# %%
dataset = ISIC('data_window_7')

# %%
class ImbalancedDatasetSampler(torch.utils.data.sampler.Sampler):
    """Samples elements randomly from a given list of indices for imbalanced dataset
    Arguments:
        indices (list, optional): a list of indices
        num_samples (int, optional): number of samples to draw
    """

    def __init__(self, data, indices=None, num_samples=None):

        # if indices is not provided,
        # all elements in the dataset will be considered
        self.indices = list(range(len(data)))             if indices is None else indices

        # if num_samples is not provided,
        # draw `len(indices)` samples in each iteration
        self.num_samples = len(self.indices)             if num_samples is None else num_samples

        # distribution of classes in the dataset
        label_to_count = {}
        for idx in self.indices:
            label = self._get_label(data, idx)
            if label in label_to_count:
                label_to_count[label] += 1
            else:
                label_to_count[label] = 1

        # weight for each sample
        weights = [1.0 / label_to_count[self._get_label(data, idx)]
                   for idx in self.indices]
        self.weights = torch.DoubleTensor(weights)

    def _get_label(self, data, idx):
        dataset_type = type(data)
        if dataset_type is torchvision.datasets.MNIST:
            return dataset.train_labels[idx].item()
        elif dataset_type is torchvision.datasets.ImageFolder:
            return dataset.imgs[idx][1]
        else:
            raw_indices = data.indices[idx]
            return data.dataset.label[raw_indices]

    def __iter__(self):
        return (self.indices[i] for i in torch.multinomial(
            self.weights, self.num_samples, replacement=True))

    def __len__(self):
        return self.num_samples

# %%
from torch.utils.data import DataLoader
import torchvision
n_train = len(dataset)
split = n_train // 8
trainset, valset = torch.utils.data.random_split(dataset, [n_train-split, split])
train_loader = DataLoader(dataset=trainset, sampler=ImbalancedDatasetSampler(trainset),
                              num_workers=4,batch_size=1024,pin_memory=True)
test_loader  = DataLoader(dataset=valset, shuffle=True,
                              num_workers=0,batch_size=1024,pin_memory=True)

# %%
data,label = next(iter(train_loader))
print(data.shape)
# Out:
# torch.Size([1024, 7, 26])

# %%
print(label.shape)
# Out:
# torch.Size([1024])

# %%
class RNN(nn.Module):
    def __init__(self):
        super(RNN,self).__init__()

        self.rnn = nn.LSTM(
            input_size=INPUT_SIZE,
            hidden_size=64,
            num_layers=1,
            batch_first=True,
        )
        self.out = nn.Linear(64,1)

    def forward(self, x):
        r_out,(h_n, h_c) = self.rnn(x,None)
        out = self.out(r_out[:,-1,:])
        return out
INPUT_SIZE = 26 #feature_size
rnn =RNN()

# %%
F = torch.nn.Sigmoid()
def train(epoch):
    nb_classes = 2
    confusion_matrix = torch.zeros(nb_classes, nb_classes)
    loss_sum = 0
    acc_sum = 0
    rnn.train()
    for i,(x,y) in enumerate(train_loader):
        b_x = Variable(x.float().cuda())     # reshape x to (batch,time_step,input_size)
        b_y = Variable(y.view(-1,1).float().cuda())

        output = rnn(b_x)
        loss = loss_func(output,b_y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        result = F(output)
        predicted = (result.data>0.5).float()
        #             total += a.size(0)
        #             correct += (predicted == a.data).sum()
        for t, p in zip(b_y.view(-1), predicted.view(-1)):
            confusion_matrix[t.long(), p.long()] += 1
            

        acc = confusion_matrix.diag() / confusion_matrix.sum(1)
        acc_non = acc[0]
        acc_in = acc[1]
        mean_acc = torch.mean(acc)
        
        iter_loss = loss.data.item()      
        loss_sum += float(iter_loss)
        write_loss.add_scalar('epoch/loss', iter_loss, epoch*len(train_loader) + i)
        
        if (i+1) % 10 == 0:
                print("Epoch [%d/%d], Iter [%d/%d] Loss: %.4f Acc: %d %%" %(epoch+1, total_epoch, i+1, len(train_loader),
                                                                            loss.data.item(),100*float(mean_acc)))
    return  float(loss_sum)/len(train_loader), float(acc_non),float(acc_in)

def test(epoch):
    rnn.eval()
    correct = 0
    total = 0
    loss_sum_t = 0
    nb_classes = 2
    confusion_matrix = torch.zeros(nb_classes, nb_classes)
    with torch.no_grad():
        for x,y in test_loader:
            b_x = Variable(x.float().cuda()) # reshape x to (batch,time_step,input_size)
            a = y
            b_y = Variable(y.view(-1,1).float().cuda())
            output = rnn(b_x)
            loss_test = loss_func(output,b_y)
            outputs = F(output)
            iter_loss_t = loss_test.data.item()
            loss_sum_t += float(iter_loss_t)
            predicted = (outputs.data>0.5).float()
        #             total += a.size(0)
        #             correct += (predicted == a.data).sum()
            for t, p in zip(a.view(-1), predicted.view(-1)):
                confusion_matrix[t.long(), p.long()] += 1
        acc = confusion_matrix.diag() / confusion_matrix.sum(1)
        acc_non = acc[0]
        acc_in = acc[1]
        mean_acc = torch.mean(acc)
    print('Accuracy of the model on the aki negative sequence: %d %%' % (100 * float(acc_non)))
    print('Accuracy of the model on the aki positive sequence: %d %%' % (100*float(acc_in)))
    return float(acc_non), float(acc_in),float(loss_sum_t) / len(test_loader)

# %%
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        save_filename_c = 'simple_lstm-7_max-acc.pt'
        save_path_c = os.path.join(save_dir, save_filename_c)
        torch.save(rnn.state_dict(), save_path_c)
        self.val_loss_min = val_loss

# %%
from torch.optim.lr_scheduler import StepLR
from tensorboardX import SummaryWriter
LR = 0.1
total_epoch = 100
optimizer = torch.optim.Adam(rnn.parameters(),lr=LR)
loss_func = nn.BCEWithLogitsLoss().cuda()
rnn.cuda()
classes = ('aki_neg','aki_pos')
# optimizer = torch.optim.Adam(model.fc.parameters(), lr=lr,weight_decay=4e-5)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min',patience=5)
acc_best = 0
total_epoch = 100
save_dir = '/home/jiahao/code/SPH6004/mimiciv_aki/model/'
write_loss = SummaryWriter('/home/jiahao/code/SPH6004/mimiciv_aki/log/simple_lstm_tw-7')

# %%
import os
from torch.autograd import Variable
early_stopping = EarlyStopping(patience=10, verbose=True)
for epoch in range(total_epoch):
    loss_mean,acc_non,acc_in = train(epoch)
    specificity,sensitivity,loss_t = test(epoch)
    scheduler.step(loss_t)
    write_loss.add_scalars('loss_acc/epoch',{
        'train_loss':loss_mean,
        'train_acc_neg':acc_non,
        'train_acc_pos':acc_in,
        'test_specificity':specificity,
        'test_sensitivity':sensitivity,
        'test_loss': loss_t,
    },epoch)

    if epoch % 10 == 0 :
        save_filename =  'simple_lstm-7_epoch-'+str(epoch)+'.pth'
        save_path = os.path.join(save_dir, save_filename)
        torch.save(rnn.state_dict(), save_path)
    
    early_stopping(loss_t,rnn)
    if early_stopping.early_stop:
        print("Early stopping")
        break
    
name = 'simple_lstm-7_final'+'.pth'
path = os.path.join(save_dir, name)
torch.save(rnn.state_dict(), path)
# Out:
# Epoch [1/100], Iter [10/3189] Loss: 0.4728 Acc: 72 %
# Epoch [1/100], Iter [20/3189] Loss: 0.5599 Acc: 73 %
# Epoch [1/100], Iter [30/3189] Loss: 0.4512 Acc: 74 %
# Epoch [1/100], Iter [40/3189] Loss: 0.4399 Acc: 75 %
# Epoch [1/100], Iter [50/3189] Loss: 0.4269 Acc: 76 %
# Epoch [1/100], Iter [60/3189] Loss: 0.4626 Acc: 77 %
# Epoch [1/100], Iter [70/3189] Loss: 0.4090 Acc: 77 %
# Epoch [1/100], Iter [80/3189] Loss: 0.4267 Acc: 77 %
# Epoch [1/100], Iter [90/3189] Loss: 0.3958 Acc: 78 %
# Epoch [1/100], Iter [100/3189] Loss: 0.4692 Acc: 78 %
# Epoch [1/100], Iter [110/3189] Loss: 0.4367 Acc: 78 %
# Epoch [1/100], Iter [120/3189] Loss: 0.4607 Acc: 79 %
# Epoch [1/100], Iter [130/3189] Loss: 0.4880 Acc: 79 %
# Epoch [1/100], Iter [140/3189] Loss: 0.4302 Acc: 79 %
# Epoch [1/100], Iter [150/3189] Loss: 0.4231 Acc: 79 %
# Epoch [1/100], Iter [160/3189] Loss: 0.3981 Acc: 79 %
# Epoch [1/100], Iter [170/3189] Loss: 0.4253 Acc: 79 %
# Epoch [1/100], Iter [180/3189] Loss: 0.4258 Acc: 79 %
# Epoch [1/100], Iter [190/3189] Loss: 0.4190 Acc: 79 %
# Epoch [1/100], Iter [200/3189] Loss: 0.4237 Acc: 79 %
# Epoch [1/100], Iter [210/3189] Loss: 0.4273 Acc: 79 %
# Epoch [1/100], Iter [220/3189] Loss: 0.4141 Acc: 79 %
# Epoch [1/100], Iter [230/3189] Loss: 0.4224 Acc: 79 %
# Epoch [1/100], Iter [240/3189] Loss: 0.4004 Acc: 79 %
# Epoch [1/100], Iter [250/3189] Loss: 0.4344 Acc: 79 %
# Epoch [1/100], Iter [260/3189] Loss: 0.4285 Acc: 79 %
# Epoch [1/100], Iter [270/3189] Loss: 0.4353 Acc: 80 %
# Epoch [1/100], Iter [280/3189] Loss: 0.3867 Acc: 80 %
# Epoch [1/100], Iter [290/3189] Loss: 0.4432 Acc: 79 %
# Epoch [1/100], Iter [300/3189] Loss: 0.4926 Acc: 79 %
# Epoch [1/100], Iter [310/3189] Loss: 0.5459 Acc: 79 %
# Epoch [1/100], Iter [320/3189] Loss: 0.4838 Acc: 79 %
# Epoch [1/100], Iter [330/3189] Loss: 0.4766 Acc: 79 %
# Epoch [1/100], Iter [340/3189] Loss: 0.4774 Acc: 79 %
# Epoch [1/100], Iter [350/3189] Loss: 0.4695 Acc: 79 %
# Epoch [1/100], Iter [360/3189] Loss: 0.4604 Acc: 79 %
# Epoch [1/100], Iter [370/3189] Loss: 0.4549 Acc: 79 %
# Epoch [1/100], Iter [380/3189] Loss: 0.4314 Acc: 79 %
# Epoch [1/100], Iter [390/3189] Loss: 0.4484 Acc: 79 %
# Epoch [1/100], Iter [400/3189] Loss: 0.4410 Acc: 79 %
# Epoch [1/100], Iter [410/3189] Loss: 0.4050 Acc: 79 %
# Epoch [1/100], Iter [420/3189] Loss: 0.4096 Acc: 79 %
# Epoch [1/100], Iter [430/3189] Loss: 0.4286 Acc: 79 %
# Epoch [1/100], Iter [440/3189] Loss: 0.3973 Acc: 79 %
# Epoch [1/100], Iter [450/3189] Loss: 0.4364 Acc: 79 %
# Epoch [1/100], Iter [460/3189] Loss: 0.4239 Acc: 79 %
# Epoch [1/100], Iter [470/3189] Loss: 0.4540 Acc: 79 %
# Epoch [1/100], Iter [480/3189] Loss: 0.4352 Acc: 79 %
# Epoch [1/100], Iter [490/3189] Loss: 0.3817 Acc: 79 %
# Epoch [1/100], Iter [500/3189] Loss: 0.4382 Acc: 79 %
# Epoch [1/100], Iter [510/3189] Loss: 0.5222 Acc: 79 %
# Epoch [1/100], Iter [520/3189] Loss: 0.5180 Acc: 79 %
# Epoch [1/100], Iter [530/3189] Loss: 0.4827 Acc: 79 %
# Epoch [1/100], Iter [540/3189] Loss: 0.4450 Acc: 79 %
# Epoch [1/100], Iter [550/3189] Loss: 0.4522 Acc: 79 %
# Epoch [1/100], Iter [560/3189] Loss: 0.4005 Acc: 79 %
# Epoch [1/100], Iter [570/3189] Loss: 0.4685 Acc: 79 %
# Epoch [1/100], Iter [580/3189] Loss: 0.4197 Acc: 79 %
# Epoch [1/100], Iter [590/3189] Loss: 0.4032 Acc: 79 %
# Epoch [1/100], Iter [600/3189] Loss: 0.4469 Acc: 79 %
# Epoch [1/100], Iter [610/3189] Loss: 0.3947 Acc: 79 %
# Epoch [1/100], Iter [620/3189] Loss: 0.4124 Acc: 79 %
# Epoch [1/100], Iter [630/3189] Loss: 0.3902 Acc: 79 %
# Epoch [1/100], Iter [640/3189] Loss: 0.4401 Acc: 79 %
# Epoch [1/100], Iter [650/3189] Loss: 0.4666 Acc: 79 %
# Epoch [1/100], Iter [660/3189] Loss: 0.4109 Acc: 79 %
# Epoch [1/100], Iter [670/3189] Loss: 0.4098 Acc: 79 %
# Epoch [1/100], Iter [680/3189] Loss: 0.4309 Acc: 79 %
# Epoch [1/100], Iter [690/3189] Loss: 0.4103 Acc: 79 %
# Epoch [1/100], Iter [700/3189] Loss: 0.4143 Acc: 79 %
# Epoch [1/100], Iter [710/3189] Loss: 0.4164 Acc: 79 %
# Epoch [1/100], Iter [720/3189] Loss: 0.3849 Acc: 79 %
# Epoch [1/100], Iter [730/3189] Loss: 0.3898 Acc: 79 %
# Epoch [1/100], Iter [740/3189] Loss: 0.3977 Acc: 79 %
# Epoch [1/100], Iter [750/3189] Loss: 0.3948 Acc: 79 %
# Epoch [1/100], Iter [760/3189] Loss: 0.3989 Acc: 79 %
# Epoch [1/100], Iter [770/3189] Loss: 0.4353 Acc: 79 %
# Epoch [1/100], Iter [780/3189] Loss: 0.4115 Acc: 79 %
# Epoch [1/100], Iter [790/3189] Loss: 0.3958 Acc: 79 %
# Epoch [1/100], Iter [800/3189] Loss: 0.3750 Acc: 79 %
# Epoch [1/100], Iter [810/3189] Loss: 0.4061 Acc: 79 %
# Epoch [1/100], Iter [820/3189] Loss: 0.4064 Acc: 79 %
# Epoch [1/100], Iter [830/3189] Loss: 0.4110 Acc: 79 %
# Epoch [1/100], Iter [840/3189] Loss: 0.4145 Acc: 79 %
# Epoch [1/100], Iter [850/3189] Loss: 0.4196 Acc: 79 %
# Epoch [1/100], Iter [860/3189] Loss: 0.4173 Acc: 79 %
# Epoch [1/100], Iter [870/3189] Loss: 0.4612 Acc: 79 %
# Epoch [1/100], Iter [880/3189] Loss: 0.4361 Acc: 79 %
# Epoch [1/100], Iter [890/3189] Loss: 0.4307 Acc: 79 %
# Epoch [1/100], Iter [900/3189] Loss: 0.4228 Acc: 79 %
# Epoch [1/100], Iter [910/3189] Loss: 0.4431 Acc: 79 %
# Epoch [1/100], Iter [920/3189] Loss: 0.4277 Acc: 79 %
# Epoch [1/100], Iter [930/3189] Loss: 0.3886 Acc: 79 %
# Epoch [1/100], Iter [940/3189] Loss: 0.3857 Acc: 79 %
# Epoch [1/100], Iter [950/3189] Loss: 0.4107 Acc: 79 %
# Epoch [1/100], Iter [960/3189] Loss: 0.4268 Acc: 79 %
# Epoch [1/100], Iter [970/3189] Loss: 0.3987 Acc: 79 %
# Epoch [1/100], Iter [980/3189] Loss: 0.4255 Acc: 79 %
# Epoch [1/100], Iter [990/3189] Loss: 0.4022 Acc: 79 %
# Epoch [1/100], Iter [1000/3189] Loss: 0.4286 Acc: 79 %
# Epoch [1/100], Iter [1010/3189] Loss: 0.4152 Acc: 79 %
# Epoch [1/100], Iter [1020/3189] Loss: 0.4415 Acc: 79 %
# Epoch [1/100], Iter [1030/3189] Loss: 0.4426 Acc: 79 %
# Epoch [1/100], Iter [1040/3189] Loss: 0.4593 Acc: 79 %
# Epoch [1/100], Iter [1050/3189] Loss: 0.4731 Acc: 79 %
# Epoch [1/100], Iter [1060/3189] Loss: 0.4328 Acc: 79 %
# Epoch [1/100], Iter [1070/3189] Loss: 0.4512 Acc: 79 %
# Epoch [1/100], Iter [1080/3189] Loss: 0.4852 Acc: 79 %
# Epoch [1/100], Iter [1090/3189] Loss: 0.4241 Acc: 79 %
# Epoch [1/100], Iter [1100/3189] Loss: 0.4296 Acc: 79 %
# Epoch [1/100], Iter [1110/3189] Loss: 0.4373 Acc: 79 %
# Epoch [1/100], Iter [1120/3189] Loss: 0.4404 Acc: 79 %
# Epoch [1/100], Iter [1130/3189] Loss: 0.4120 Acc: 79 %
# Epoch [1/100], Iter [1140/3189] Loss: 0.4210 Acc: 79 %
# Epoch [1/100], Iter [1150/3189] Loss: 0.4020 Acc: 79 %
# Epoch [1/100], Iter [1160/3189] Loss: 0.4068 Acc: 79 %
# Epoch [1/100], Iter [1170/3189] Loss: 0.4309 Acc: 79 %
# Epoch [1/100], Iter [1180/3189] Loss: 0.4666 Acc: 79 %
# Epoch [1/100], Iter [1190/3189] Loss: 0.4348 Acc: 79 %
# Epoch [1/100], Iter [1200/3189] Loss: 0.4167 Acc: 79 %
# Epoch [1/100], Iter [1210/3189] Loss: 0.4477 Acc: 79 %
# Epoch [1/100], Iter [1220/3189] Loss: 0.4269 Acc: 79 %
# Epoch [1/100], Iter [1230/3189] Loss: 0.4031 Acc: 79 %
# Epoch [1/100], Iter [1240/3189] Loss: 0.4592 Acc: 79 %
# Epoch [1/100], Iter [1250/3189] Loss: 0.4156 Acc: 79 %
# Epoch [1/100], Iter [1260/3189] Loss: 0.4230 Acc: 79 %
# Epoch [1/100], Iter [1270/3189] Loss: 0.4369 Acc: 79 %
# Epoch [1/100], Iter [1280/3189] Loss: 0.4045 Acc: 79 %
# Epoch [1/100], Iter [1290/3189] Loss: 0.4110 Acc: 79 %
# Epoch [1/100], Iter [1300/3189] Loss: 0.4129 Acc: 79 %
# Epoch [1/100], Iter [1310/3189] Loss: 0.3826 Acc: 79 %
# Epoch [1/100], Iter [1320/3189] Loss: 0.4028 Acc: 79 %
# Epoch [1/100], Iter [1330/3189] Loss: 0.4080 Acc: 79 %
# Epoch [1/100], Iter [1340/3189] Loss: 0.3903 Acc: 79 %
# Epoch [1/100], Iter [1350/3189] Loss: 0.3699 Acc: 79 %
# Epoch [1/100], Iter [1360/3189] Loss: 0.3893 Acc: 79 %
# Epoch [1/100], Iter [1370/3189] Loss: 0.3915 Acc: 79 %
# Epoch [1/100], Iter [1380/3189] Loss: 0.3413 Acc: 79 %
# Epoch [1/100], Iter [1390/3189] Loss: 0.4148 Acc: 79 %
# Epoch [1/100], Iter [1400/3189] Loss: 0.4402 Acc: 79 %
# Epoch [1/100], Iter [1410/3189] Loss: 0.3959 Acc: 79 %
# Epoch [1/100], Iter [1420/3189] Loss: 0.3884 Acc: 79 %
# Epoch [1/100], Iter [1430/3189] Loss: 0.4058 Acc: 79 %
# Epoch [1/100], Iter [1440/3189] Loss: 0.3880 Acc: 79 %
# Epoch [1/100], Iter [1450/3189] Loss: 0.3899 Acc: 79 %
# Epoch [1/100], Iter [1460/3189] Loss: 0.3982 Acc: 79 %
# Epoch [1/100], Iter [1470/3189] Loss: 0.4079 Acc: 79 %
# Epoch [1/100], Iter [1480/3189] Loss: 0.3893 Acc: 79 %
# Epoch [1/100], Iter [1490/3189] Loss: 0.3801 Acc: 79 %
# Epoch [1/100], Iter [1500/3189] Loss: 0.3820 Acc: 79 %
# Epoch [1/100], Iter [1510/3189] Loss: 0.3853 Acc: 79 %
# Epoch [1/100], Iter [1520/3189] Loss: 0.3991 Acc: 79 %
# Epoch [1/100], Iter [1530/3189] Loss: 0.4007 Acc: 79 %
# Epoch [1/100], Iter [1540/3189] Loss: 0.3976 Acc: 79 %
# Epoch [1/100], Iter [1550/3189] Loss: 0.3770 Acc: 79 %
# Epoch [1/100], Iter [1560/3189] Loss: 0.3905 Acc: 79 %
# Epoch [1/100], Iter [1570/3189] Loss: 0.3957 Acc: 79 %
# Epoch [1/100], Iter [1580/3189] Loss: 0.3949 Acc: 79 %
# Epoch [1/100], Iter [1590/3189] Loss: 0.4147 Acc: 79 %
# Epoch [1/100], Iter [1600/3189] Loss: 0.3978 Acc: 79 %
# Epoch [1/100], Iter [1610/3189] Loss: 0.3987 Acc: 79 %
# Epoch [1/100], Iter [1620/3189] Loss: 0.4188 Acc: 79 %
# Epoch [1/100], Iter [1630/3189] Loss: 0.4038 Acc: 79 %
# Epoch [1/100], Iter [1640/3189] Loss: 0.3993 Acc: 79 %
# Epoch [1/100], Iter [1650/3189] Loss: 0.3806 Acc: 79 %
# Epoch [1/100], Iter [1660/3189] Loss: 0.3743 Acc: 79 %
# Epoch [1/100], Iter [1670/3189] Loss: 0.3700 Acc: 79 %
# Epoch [1/100], Iter [1680/3189] Loss: 0.4008 Acc: 79 %
# Epoch [1/100], Iter [1690/3189] Loss: 0.3829 Acc: 79 %
# Epoch [1/100], Iter [1700/3189] Loss: 0.3864 Acc: 79 %
# Epoch [1/100], Iter [1710/3189] Loss: 0.4074 Acc: 79 %
# Epoch [1/100], Iter [1720/3189] Loss: 0.4044 Acc: 79 %
# Epoch [1/100], Iter [1730/3189] Loss: 0.4254 Acc: 79 %
# Epoch [1/100], Iter [1740/3189] Loss: 0.4284 Acc: 79 %
# Epoch [1/100], Iter [1750/3189] Loss: 0.3969 Acc: 79 %
# Epoch [1/100], Iter [1760/3189] Loss: 0.4002 Acc: 79 %
# Epoch [1/100], Iter [1770/3189] Loss: 0.3947 Acc: 79 %
# Epoch [1/100], Iter [1780/3189] Loss: 0.3700 Acc: 79 %
# Epoch [1/100], Iter [1790/3189] Loss: 0.3947 Acc: 79 %
# Epoch [1/100], Iter [1800/3189] Loss: 0.4275 Acc: 80 %
# Epoch [1/100], Iter [1810/3189] Loss: 0.3853 Acc: 80 %
# Epoch [1/100], Iter [1820/3189] Loss: 0.3908 Acc: 80 %
# Epoch [1/100], Iter [1830/3189] Loss: 0.3790 Acc: 80 %
# Epoch [1/100], Iter [1840/3189] Loss: 0.3810 Acc: 80 %
# Epoch [1/100], Iter [1850/3189] Loss: 0.3853 Acc: 80 %
# Epoch [1/100], Iter [1860/3189] Loss: 0.4215 Acc: 80 %
# Epoch [1/100], Iter [1870/3189] Loss: 0.4321 Acc: 80 %
# Epoch [1/100], Iter [1880/3189] Loss: 0.4096 Acc: 80 %
# Epoch [1/100], Iter [1890/3189] Loss: 0.3971 Acc: 80 %
# Epoch [1/100], Iter [1900/3189] Loss: 0.3895 Acc: 80 %
# Epoch [1/100], Iter [1910/3189] Loss: 0.3922 Acc: 80 %
# Epoch [1/100], Iter [1920/3189] Loss: 0.4043 Acc: 80 %
# Epoch [1/100], Iter [1930/3189] Loss: 0.4047 Acc: 80 %
# Epoch [1/100], Iter [1940/3189] Loss: 0.3726 Acc: 80 %
# Epoch [1/100], Iter [1950/3189] Loss: 0.3825 Acc: 80 %
# Epoch [1/100], Iter [1960/3189] Loss: 0.4007 Acc: 80 %
# Epoch [1/100], Iter [1970/3189] Loss: 0.3953 Acc: 80 %
# Epoch [1/100], Iter [1980/3189] Loss: 0.3653 Acc: 80 %
# Epoch [1/100], Iter [1990/3189] Loss: 0.3923 Acc: 80 %
# Epoch [1/100], Iter [2000/3189] Loss: 0.3619 Acc: 80 %
# Epoch [1/100], Iter [2010/3189] Loss: 0.3523 Acc: 80 %
# Epoch [1/100], Iter [2020/3189] Loss: 0.3532 Acc: 80 %
# Epoch [1/100], Iter [2030/3189] Loss: 0.3414 Acc: 80 %
# Epoch [1/100], Iter [2040/3189] Loss: 0.3496 Acc: 80 %
# Epoch [1/100], Iter [2050/3189] Loss: 0.3791 Acc: 80 %
# Epoch [1/100], Iter [2060/3189] Loss: 0.3716 Acc: 80 %
# Epoch [1/100], Iter [2070/3189] Loss: 0.3550 Acc: 80 %
# Epoch [1/100], Iter [2080/3189] Loss: 0.3748 Acc: 80 %
# Epoch [1/100], Iter [2090/3189] Loss: 0.3917 Acc: 80 %
# Epoch [1/100], Iter [2100/3189] Loss: 0.3935 Acc: 80 %
# Epoch [1/100], Iter [2110/3189] Loss: 0.3744 Acc: 80 %
# Epoch [1/100], Iter [2120/3189] Loss: 0.3649 Acc: 80 %
# Epoch [1/100], Iter [2130/3189] Loss: 0.3619 Acc: 80 %
# Epoch [1/100], Iter [2140/3189] Loss: 0.3669 Acc: 80 %
# Epoch [1/100], Iter [2150/3189] Loss: 0.3513 Acc: 80 %
# Epoch [1/100], Iter [2160/3189] Loss: 0.3761 Acc: 80 %
# Epoch [1/100], Iter [2170/3189] Loss: 0.3978 Acc: 80 %
# Epoch [1/100], Iter [2180/3189] Loss: 0.3786 Acc: 80 %
# Epoch [1/100], Iter [2190/3189] Loss: 0.3306 Acc: 80 %
# Epoch [1/100], Iter [2200/3189] Loss: 0.3554 Acc: 80 %
# Epoch [1/100], Iter [2210/3189] Loss: 0.4025 Acc: 80 %
# Epoch [1/100], Iter [2220/3189] Loss: 0.3759 Acc: 80 %
# Epoch [1/100], Iter [2230/3189] Loss: 0.3652 Acc: 80 %
# Epoch [1/100], Iter [2240/3189] Loss: 0.3152 Acc: 80 %
# Epoch [1/100], Iter [2250/3189] Loss: 0.3589 Acc: 80 %
# Epoch [1/100], Iter [2260/3189] Loss: 0.3335 Acc: 80 %
# Epoch [1/100], Iter [2270/3189] Loss: 0.3732 Acc: 80 %
# Epoch [1/100], Iter [2280/3189] Loss: 0.3660 Acc: 80 %
# Epoch [1/100], Iter [2290/3189] Loss: 0.3688 Acc: 80 %
# Epoch [1/100], Iter [2300/3189] Loss: 0.3885 Acc: 80 %
# Epoch [1/100], Iter [2310/3189] Loss: 0.3905 Acc: 80 %
# Epoch [1/100], Iter [2320/3189] Loss: 0.3809 Acc: 80 %
# Epoch [1/100], Iter [2330/3189] Loss: 0.3618 Acc: 80 %
# Epoch [1/100], Iter [2340/3189] Loss: 0.3715 Acc: 80 %
# Epoch [1/100], Iter [2350/3189] Loss: 0.3564 Acc: 80 %
# Epoch [1/100], Iter [2360/3189] Loss: 0.3674 Acc: 80 %
# Epoch [1/100], Iter [2370/3189] Loss: 0.3742 Acc: 80 %
# Epoch [1/100], Iter [2380/3189] Loss: 0.4090 Acc: 80 %
# Epoch [1/100], Iter [2390/3189] Loss: 0.3669 Acc: 80 %
# Epoch [1/100], Iter [2400/3189] Loss: 0.3614 Acc: 80 %
# Epoch [1/100], Iter [2410/3189] Loss: 0.3824 Acc: 80 %
# Epoch [1/100], Iter [2420/3189] Loss: 0.3841 Acc: 80 %
# Epoch [1/100], Iter [2430/3189] Loss: 0.3835 Acc: 80 %
# Epoch [1/100], Iter [2440/3189] Loss: 0.3645 Acc: 80 %
# Epoch [1/100], Iter [2450/3189] Loss: 0.3819 Acc: 80 %
# Epoch [1/100], Iter [2460/3189] Loss: 0.3826 Acc: 80 %
# Epoch [1/100], Iter [2470/3189] Loss: 0.3524 Acc: 80 %
# Epoch [1/100], Iter [2480/3189] Loss: 0.4039 Acc: 80 %
# Epoch [1/100], Iter [2490/3189] Loss: 0.3735 Acc: 80 %
# Epoch [1/100], Iter [2500/3189] Loss: 0.3398 Acc: 80 %
# Epoch [1/100], Iter [2510/3189] Loss: 0.3862 Acc: 80 %
# Epoch [1/100], Iter [2520/3189] Loss: 0.3580 Acc: 80 %
# Epoch [1/100], Iter [2530/3189] Loss: 0.3720 Acc: 80 %
# Epoch [1/100], Iter [2540/3189] Loss: 0.3503 Acc: 80 %
# Epoch [1/100], Iter [2550/3189] Loss: 0.3883 Acc: 80 %
# Epoch [1/100], Iter [2560/3189] Loss: 0.3676 Acc: 80 %
# Epoch [1/100], Iter [2570/3189] Loss: 0.3920 Acc: 80 %
# Epoch [1/100], Iter [2580/3189] Loss: 0.3644 Acc: 80 %
# Epoch [1/100], Iter [2590/3189] Loss: 0.3577 Acc: 80 %
# Epoch [1/100], Iter [2600/3189] Loss: 0.3663 Acc: 80 %
# Epoch [1/100], Iter [2610/3189] Loss: 0.3690 Acc: 80 %
# Epoch [1/100], Iter [2620/3189] Loss: 0.3533 Acc: 80 %
# Epoch [1/100], Iter [2630/3189] Loss: 0.3648 Acc: 80 %
# Epoch [1/100], Iter [2640/3189] Loss: 0.3388 Acc: 80 %
# Epoch [1/100], Iter [2650/3189] Loss: 0.3374 Acc: 80 %
# Epoch [1/100], Iter [2660/3189] Loss: 0.3715 Acc: 80 %
# Epoch [1/100], Iter [2670/3189] Loss: 0.3296 Acc: 80 %
# Epoch [1/100], Iter [2680/3189] Loss: 0.3599 Acc: 80 %
# Epoch [1/100], Iter [2690/3189] Loss: 0.3587 Acc: 80 %
# Epoch [1/100], Iter [2700/3189] Loss: 0.3506 Acc: 80 %
# Epoch [1/100], Iter [2710/3189] Loss: 0.4003 Acc: 80 %
# Epoch [1/100], Iter [2720/3189] Loss: 0.4017 Acc: 80 %
# Epoch [1/100], Iter [2730/3189] Loss: 0.4343 Acc: 80 %
# Epoch [1/100], Iter [2740/3189] Loss: 0.3552 Acc: 80 %
# Epoch [1/100], Iter [2750/3189] Loss: 0.3863 Acc: 80 %
# Epoch [1/100], Iter [2760/3189] Loss: 0.3727 Acc: 80 %
# Epoch [1/100], Iter [2770/3189] Loss: 0.3509 Acc: 80 %
# Epoch [1/100], Iter [2780/3189] Loss: 0.3431 Acc: 80 %
# Epoch [1/100], Iter [2790/3189] Loss: 0.3652 Acc: 80 %
# Epoch [1/100], Iter [2800/3189] Loss: 0.4400 Acc: 80 %
# Epoch [1/100], Iter [2810/3189] Loss: 0.4143 Acc: 80 %
# Epoch [1/100], Iter [2820/3189] Loss: 0.4454 Acc: 80 %
# Epoch [1/100], Iter [2830/3189] Loss: 0.4625 Acc: 80 %
# Epoch [1/100], Iter [2840/3189] Loss: 0.4699 Acc: 80 %
# Epoch [1/100], Iter [2850/3189] Loss: 0.4378 Acc: 80 %
# Epoch [1/100], Iter [2860/3189] Loss: 0.4382 Acc: 80 %
# Epoch [1/100], Iter [2870/3189] Loss: 0.4091 Acc: 80 %
# Epoch [1/100], Iter [2880/3189] Loss: 0.3764 Acc: 80 %
# Epoch [1/100], Iter [2890/3189] Loss: 0.3651 Acc: 80 %
# Epoch [1/100], Iter [2900/3189] Loss: 0.3560 Acc: 80 %
# Epoch [1/100], Iter [2910/3189] Loss: 0.3557 Acc: 80 %
# Epoch [1/100], Iter [2920/3189] Loss: 0.3952 Acc: 80 %
# Epoch [1/100], Iter [2930/3189] Loss: 0.3685 Acc: 80 %
# Epoch [1/100], Iter [2940/3189] Loss: 0.3615 Acc: 80 %
# Epoch [1/100], Iter [2950/3189] Loss: 0.3684 Acc: 80 %
# Epoch [1/100], Iter [2960/3189] Loss: 0.3763 Acc: 80 %
# Epoch [1/100], Iter [2970/3189] Loss: 0.3629 Acc: 80 %
# Epoch [1/100], Iter [2980/3189] Loss: 0.3720 Acc: 80 %
# Epoch [1/100], Iter [2990/3189] Loss: 0.3560 Acc: 80 %
# Epoch [1/100], Iter [3000/3189] Loss: 0.3553 Acc: 80 %
# Epoch [1/100], Iter [3010/3189] Loss: 0.3337 Acc: 80 %
# Epoch [1/100], Iter [3020/3189] Loss: 0.3970 Acc: 80 %
# Epoch [1/100], Iter [3030/3189] Loss: 0.3662 Acc: 80 %
# Epoch [1/100], Iter [3040/3189] Loss: 0.3583 Acc: 80 %
# Epoch [1/100], Iter [3050/3189] Loss: 0.3372 Acc: 80 %
# Epoch [1/100], Iter [3060/3189] Loss: 0.3623 Acc: 80 %
# Epoch [1/100], Iter [3070/3189] Loss: 0.3496 Acc: 80 %
# Epoch [1/100], Iter [3080/3189] Loss: 0.3690 Acc: 80 %
# Epoch [1/100], Iter [3090/3189] Loss: 0.3278 Acc: 80 %
# Epoch [1/100], Iter [3100/3189] Loss: 0.3960 Acc: 80 %
# Epoch [1/100], Iter [3110/3189] Loss: 0.3666 Acc: 80 %
# Epoch [1/100], Iter [3120/3189] Loss: 0.3668 Acc: 80 %
# Epoch [1/100], Iter [3130/3189] Loss: 0.3606 Acc: 80 %
# Epoch [1/100], Iter [3140/3189] Loss: 0.3693 Acc: 80 %
# Epoch [1/100], Iter [3150/3189] Loss: 0.3325 Acc: 80 %
# Epoch [1/100], Iter [3160/3189] Loss: 0.3422 Acc: 80 %
# Epoch [1/100], Iter [3170/3189] Loss: 0.3633 Acc: 80 %
# Epoch [1/100], Iter [3180/3189] Loss: 0.3338 Acc: 80 %
# Accuracy of the model on the aki negative sequence: 80 %
# Accuracy of the model on the aki positive sequence: 87 %
# Validation loss decreased (inf --> 0.336570).  Saving model ...
# Epoch [2/100], Iter [10/3189] Loss: 0.3693 Acc: 82 %
# Epoch [2/100], Iter [20/3189] Loss: 0.3551 Acc: 81 %
# Epoch [2/100], Iter [30/3189] Loss: 0.3405 Acc: 82 %
# Epoch [2/100], Iter [40/3189] Loss: 0.3602 Acc: 82 %
# Epoch [2/100], Iter [50/3189] Loss: 0.3741 Acc: 82 %
# Epoch [2/100], Iter [60/3189] Loss: 0.3796 Acc: 82 %
# Epoch [2/100], Iter [70/3189] Loss: 0.4089 Acc: 82 %
# Epoch [2/100], Iter [80/3189] Loss: 0.3925 Acc: 82 %
# Epoch [2/100], Iter [90/3189] Loss: 0.4046 Acc: 82 %
# Epoch [2/100], Iter [100/3189] Loss: 0.3757 Acc: 82 %
# Epoch [2/100], Iter [110/3189] Loss: 0.4218 Acc: 82 %
# Epoch [2/100], Iter [120/3189] Loss: 0.4049 Acc: 82 %
# Epoch [2/100], Iter [130/3189] Loss: 0.4187 Acc: 82 %
# Epoch [2/100], Iter [140/3189] Loss: 0.4247 Acc: 81 %
# Epoch [2/100], Iter [150/3189] Loss: 0.4374 Acc: 81 %
# Epoch [2/100], Iter [160/3189] Loss: 0.4486 Acc: 81 %
# Epoch [2/100], Iter [170/3189] Loss: 0.3998 Acc: 81 %
# Epoch [2/100], Iter [180/3189] Loss: 0.4585 Acc: 81 %
# Epoch [2/100], Iter [190/3189] Loss: 0.3850 Acc: 81 %
# Epoch [2/100], Iter [200/3189] Loss: 0.4105 Acc: 81 %
# Epoch [2/100], Iter [210/3189] Loss: 0.4021 Acc: 81 %
# Epoch [2/100], Iter [220/3189] Loss: 0.4098 Acc: 81 %
# Epoch [2/100], Iter [230/3189] Loss: 0.4178 Acc: 81 %
# Epoch [2/100], Iter [240/3189] Loss: 0.4056 Acc: 81 %
# Epoch [2/100], Iter [250/3189] Loss: 0.3954 Acc: 81 %
# Epoch [2/100], Iter [260/3189] Loss: 0.4132 Acc: 81 %
# Epoch [2/100], Iter [270/3189] Loss: 0.4169 Acc: 81 %
# Epoch [2/100], Iter [280/3189] Loss: 0.4026 Acc: 81 %
# Epoch [2/100], Iter [290/3189] Loss: 0.4204 Acc: 81 %
# Epoch [2/100], Iter [300/3189] Loss: 0.4377 Acc: 81 %
# Epoch [2/100], Iter [310/3189] Loss: 0.4142 Acc: 81 %
# Epoch [2/100], Iter [320/3189] Loss: 0.4038 Acc: 81 %
# Epoch [2/100], Iter [330/3189] Loss: 0.4306 Acc: 81 %
# Epoch [2/100], Iter [340/3189] Loss: 0.4125 Acc: 81 %
# Epoch [2/100], Iter [350/3189] Loss: 0.3577 Acc: 81 %
# Epoch [2/100], Iter [360/3189] Loss: 0.3754 Acc: 81 %
# Epoch [2/100], Iter [370/3189] Loss: 0.3223 Acc: 81 %
# Epoch [2/100], Iter [380/3189] Loss: 0.3545 Acc: 81 %
# Epoch [2/100], Iter [390/3189] Loss: 0.3730 Acc: 81 %
# Epoch [2/100], Iter [400/3189] Loss: 0.3722 Acc: 81 %
# Epoch [2/100], Iter [410/3189] Loss: 0.3394 Acc: 81 %
# Epoch [2/100], Iter [420/3189] Loss: 0.3931 Acc: 81 %
# Epoch [2/100], Iter [430/3189] Loss: 0.3729 Acc: 81 %
# Epoch [2/100], Iter [440/3189] Loss: 0.3727 Acc: 81 %
# Epoch [2/100], Iter [450/3189] Loss: 0.3258 Acc: 81 %
# Epoch [2/100], Iter [460/3189] Loss: 0.3390 Acc: 82 %
# Epoch [2/100], Iter [470/3189] Loss: 0.3122 Acc: 82 %
# Epoch [2/100], Iter [480/3189] Loss: 0.3468 Acc: 82 %
# Epoch [2/100], Iter [490/3189] Loss: 0.3259 Acc: 82 %
# Epoch [2/100], Iter [500/3189] Loss: 0.3397 Acc: 82 %
# Epoch [2/100], Iter [510/3189] Loss: 0.4101 Acc: 82 %
# Epoch [2/100], Iter [520/3189] Loss: 0.3644 Acc: 82 %
# Epoch [2/100], Iter [530/3189] Loss: 0.3399 Acc: 82 %
# Epoch [2/100], Iter [540/3189] Loss: 0.3239 Acc: 82 %
# Epoch [2/100], Iter [550/3189] Loss: 0.3668 Acc: 82 %
# Epoch [2/100], Iter [560/3189] Loss: 0.3227 Acc: 82 %
# Epoch [2/100], Iter [570/3189] Loss: 0.3408 Acc: 82 %
# Epoch [2/100], Iter [580/3189] Loss: 0.3386 Acc: 82 %
# Epoch [2/100], Iter [590/3189] Loss: 0.3285 Acc: 82 %
# Epoch [2/100], Iter [600/3189] Loss: 0.3715 Acc: 82 %
# Epoch [2/100], Iter [610/3189] Loss: 0.3549 Acc: 82 %
# Epoch [2/100], Iter [620/3189] Loss: 0.3427 Acc: 82 %
# Epoch [2/100], Iter [630/3189] Loss: 0.3196 Acc: 82 %
# Epoch [2/100], Iter [640/3189] Loss: 0.3539 Acc: 82 %
# Epoch [2/100], Iter [650/3189] Loss: 0.3094 Acc: 82 %
# Epoch [2/100], Iter [660/3189] Loss: 0.3887 Acc: 82 %
# Epoch [2/100], Iter [670/3189] Loss: 0.3913 Acc: 82 %
# Epoch [2/100], Iter [680/3189] Loss: 0.3739 Acc: 82 %
# Epoch [2/100], Iter [690/3189] Loss: 0.3153 Acc: 82 %
# Epoch [2/100], Iter [700/3189] Loss: 0.3224 Acc: 82 %
# Epoch [2/100], Iter [710/3189] Loss: 0.3430 Acc: 82 %
# Epoch [2/100], Iter [720/3189] Loss: 0.3365 Acc: 82 %
# Epoch [2/100], Iter [730/3189] Loss: 0.3260 Acc: 82 %
# Epoch [2/100], Iter [740/3189] Loss: 0.3399 Acc: 82 %
# Epoch [2/100], Iter [750/3189] Loss: 0.3455 Acc: 82 %
# Epoch [2/100], Iter [760/3189] Loss: 0.3764 Acc: 82 %
# Epoch [2/100], Iter [770/3189] Loss: 0.3310 Acc: 82 %
# Epoch [2/100], Iter [780/3189] Loss: 0.3590 Acc: 82 %
# Epoch [2/100], Iter [790/3189] Loss: 0.3805 Acc: 82 %
# Epoch [2/100], Iter [800/3189] Loss: 0.3582 Acc: 82 %
# Epoch [2/100], Iter [810/3189] Loss: 0.3641 Acc: 82 %
# Epoch [2/100], Iter [820/3189] Loss: 0.3617 Acc: 82 %
# Epoch [2/100], Iter [830/3189] Loss: 0.3801 Acc: 82 %
# Epoch [2/100], Iter [840/3189] Loss: 0.3892 Acc: 82 %
# Epoch [2/100], Iter [850/3189] Loss: 0.3460 Acc: 82 %
# Epoch [2/100], Iter [860/3189] Loss: 0.3487 Acc: 82 %
# Epoch [2/100], Iter [870/3189] Loss: 0.3781 Acc: 82 %
# Epoch [2/100], Iter [880/3189] Loss: 0.3141 Acc: 82 %
# Epoch [2/100], Iter [890/3189] Loss: 0.2976 Acc: 82 %
# Epoch [2/100], Iter [900/3189] Loss: 0.3243 Acc: 82 %
# Epoch [2/100], Iter [910/3189] Loss: 0.3503 Acc: 82 %
# Epoch [2/100], Iter [920/3189] Loss: 0.3191 Acc: 82 %
# Epoch [2/100], Iter [930/3189] Loss: 0.3204 Acc: 82 %
# Epoch [2/100], Iter [940/3189] Loss: 0.3016 Acc: 82 %
# Epoch [2/100], Iter [950/3189] Loss: 0.3483 Acc: 83 %
# Epoch [2/100], Iter [960/3189] Loss: 0.3395 Acc: 83 %
# Epoch [2/100], Iter [970/3189] Loss: 0.3206 Acc: 83 %
# Epoch [2/100], Iter [980/3189] Loss: 0.3949 Acc: 83 %
# Epoch [2/100], Iter [990/3189] Loss: 0.3803 Acc: 83 %
# Epoch [2/100], Iter [1000/3189] Loss: 0.3889 Acc: 83 %
# Epoch [2/100], Iter [1010/3189] Loss: 0.3440 Acc: 83 %
# Epoch [2/100], Iter [1020/3189] Loss: 0.3430 Acc: 83 %
# Epoch [2/100], Iter [1030/3189] Loss: 0.3259 Acc: 83 %
# Epoch [2/100], Iter [1040/3189] Loss: 0.3017 Acc: 83 %
# Epoch [2/100], Iter [1050/3189] Loss: 0.3705 Acc: 83 %
# Epoch [2/100], Iter [1060/3189] Loss: 0.3621 Acc: 83 %
# Epoch [2/100], Iter [1070/3189] Loss: 0.3879 Acc: 83 %
# Epoch [2/100], Iter [1080/3189] Loss: 0.3360 Acc: 83 %
# Epoch [2/100], Iter [1090/3189] Loss: 0.3284 Acc: 83 %
# Epoch [2/100], Iter [1100/3189] Loss: 0.3283 Acc: 83 %
# Epoch [2/100], Iter [1110/3189] Loss: 0.3119 Acc: 83 %
# Epoch [2/100], Iter [1120/3189] Loss: 0.3400 Acc: 83 %
# Epoch [2/100], Iter [1130/3189] Loss: 0.3414 Acc: 83 %
# Epoch [2/100], Iter [1140/3189] Loss: 0.3550 Acc: 83 %
# Epoch [2/100], Iter [1150/3189] Loss: 0.3462 Acc: 83 %
# Epoch [2/100], Iter [1160/3189] Loss: 0.3367 Acc: 83 %
# Epoch [2/100], Iter [1170/3189] Loss: 0.3040 Acc: 83 %
# Epoch [2/100], Iter [1180/3189] Loss: 0.3107 Acc: 83 %
# Epoch [2/100], Iter [1190/3189] Loss: 0.3274 Acc: 83 %
# Epoch [2/100], Iter [1200/3189] Loss: 0.3428 Acc: 83 %
# Epoch [2/100], Iter [1210/3189] Loss: 0.3243 Acc: 83 %
# Epoch [2/100], Iter [1220/3189] Loss: 0.3384 Acc: 83 %
# Epoch [2/100], Iter [1230/3189] Loss: 0.3428 Acc: 83 %
# Epoch [2/100], Iter [1240/3189] Loss: 0.3260 Acc: 83 %
# Epoch [2/100], Iter [1250/3189] Loss: 0.3729 Acc: 83 %
# Epoch [2/100], Iter [1260/3189] Loss: 0.3499 Acc: 83 %
# Epoch [2/100], Iter [1270/3189] Loss: 0.3248 Acc: 83 %
# Epoch [2/100], Iter [1280/3189] Loss: 0.2894 Acc: 83 %
# Epoch [2/100], Iter [1290/3189] Loss: 0.3051 Acc: 83 %
# Epoch [2/100], Iter [1300/3189] Loss: 0.3515 Acc: 83 %
# Epoch [2/100], Iter [1310/3189] Loss: 0.3303 Acc: 83 %
# Epoch [2/100], Iter [1320/3189] Loss: 0.2951 Acc: 83 %
# Epoch [2/100], Iter [1330/3189] Loss: 0.3281 Acc: 83 %
# Epoch [2/100], Iter [1340/3189] Loss: 0.3367 Acc: 83 %
# Epoch [2/100], Iter [1350/3189] Loss: 0.3607 Acc: 83 %
# Epoch [2/100], Iter [1360/3189] Loss: 0.3501 Acc: 83 %
# Epoch [2/100], Iter [1370/3189] Loss: 0.3697 Acc: 83 %
# Epoch [2/100], Iter [1380/3189] Loss: 0.3689 Acc: 83 %
# Epoch [2/100], Iter [1390/3189] Loss: 0.2833 Acc: 83 %
# Epoch [2/100], Iter [1400/3189] Loss: 0.3697 Acc: 83 %
# Epoch [2/100], Iter [1410/3189] Loss: 0.3366 Acc: 83 %
# Epoch [2/100], Iter [1420/3189] Loss: 0.4018 Acc: 83 %
# Epoch [2/100], Iter [1430/3189] Loss: 0.3803 Acc: 83 %
# Epoch [2/100], Iter [1440/3189] Loss: 0.3944 Acc: 83 %
# Epoch [2/100], Iter [1450/3189] Loss: 0.3292 Acc: 83 %
# Epoch [2/100], Iter [1460/3189] Loss: 0.4250 Acc: 83 %
# Epoch [2/100], Iter [1470/3189] Loss: 0.3313 Acc: 83 %
# Epoch [2/100], Iter [1480/3189] Loss: 0.3743 Acc: 83 %
# Epoch [2/100], Iter [1490/3189] Loss: 0.3453 Acc: 83 %
# Epoch [2/100], Iter [1500/3189] Loss: 0.3343 Acc: 83 %
# Epoch [2/100], Iter [1510/3189] Loss: 0.3236 Acc: 83 %
# Epoch [2/100], Iter [1520/3189] Loss: 0.3621 Acc: 83 %
# Epoch [2/100], Iter [1530/3189] Loss: 0.3343 Acc: 83 %
# Epoch [2/100], Iter [1540/3189] Loss: 0.3265 Acc: 83 %
# Epoch [2/100], Iter [1550/3189] Loss: 0.3356 Acc: 83 %
# Epoch [2/100], Iter [1560/3189] Loss: 0.3263 Acc: 83 %
# Epoch [2/100], Iter [1570/3189] Loss: 0.3062 Acc: 83 %
# Epoch [2/100], Iter [1580/3189] Loss: 0.3280 Acc: 83 %
# Epoch [2/100], Iter [1590/3189] Loss: 0.3214 Acc: 83 %
# Epoch [2/100], Iter [1600/3189] Loss: 0.3882 Acc: 83 %
# Epoch [2/100], Iter [1610/3189] Loss: 0.3127 Acc: 83 %
# Epoch [2/100], Iter [1620/3189] Loss: 0.3389 Acc: 83 %
# Epoch [2/100], Iter [1630/3189] Loss: 0.3091 Acc: 83 %
# Epoch [2/100], Iter [1640/3189] Loss: 0.3426 Acc: 83 %
# Epoch [2/100], Iter [1650/3189] Loss: 0.3163 Acc: 83 %
# Epoch [2/100], Iter [1660/3189] Loss: 0.3488 Acc: 83 %
# Epoch [2/100], Iter [1670/3189] Loss: 0.3405 Acc: 83 %
# Epoch [2/100], Iter [1680/3189] Loss: 0.3322 Acc: 83 %
# Epoch [2/100], Iter [1690/3189] Loss: 0.3337 Acc: 83 %
# Epoch [2/100], Iter [1700/3189] Loss: 0.3265 Acc: 83 %
# Epoch [2/100], Iter [1710/3189] Loss: 0.3209 Acc: 83 %
# Epoch [2/100], Iter [1720/3189] Loss: 0.3333 Acc: 83 %
# Epoch [2/100], Iter [1730/3189] Loss: 0.3279 Acc: 83 %
# Epoch [2/100], Iter [1740/3189] Loss: 0.3623 Acc: 83 %
# Epoch [2/100], Iter [1750/3189] Loss: 0.3245 Acc: 83 %
# Epoch [2/100], Iter [1760/3189] Loss: 0.3173 Acc: 83 %
# Epoch [2/100], Iter [1770/3189] Loss: 0.3323 Acc: 83 %
# Epoch [2/100], Iter [1780/3189] Loss: 0.3340 Acc: 83 %
# Epoch [2/100], Iter [1790/3189] Loss: 0.3299 Acc: 83 %
# Epoch [2/100], Iter [1800/3189] Loss: 0.3564 Acc: 83 %
# Epoch [2/100], Iter [1810/3189] Loss: 0.3325 Acc: 83 %
# Epoch [2/100], Iter [1820/3189] Loss: 0.3030 Acc: 83 %
# Epoch [2/100], Iter [1830/3189] Loss: 0.3112 Acc: 83 %
# Epoch [2/100], Iter [1840/3189] Loss: 0.2912 Acc: 83 %
# Epoch [2/100], Iter [1850/3189] Loss: 0.2929 Acc: 83 %
# Epoch [2/100], Iter [1860/3189] Loss: 0.3281 Acc: 83 %
# Epoch [2/100], Iter [1870/3189] Loss: 0.3550 Acc: 83 %
# Epoch [2/100], Iter [1880/3189] Loss: 0.3292 Acc: 83 %
# Epoch [2/100], Iter [1890/3189] Loss: 0.3285 Acc: 83 %
# Epoch [2/100], Iter [1900/3189] Loss: 0.3190 Acc: 83 %
# Epoch [2/100], Iter [1910/3189] Loss: 0.3378 Acc: 83 %
# Epoch [2/100], Iter [1920/3189] Loss: 0.3283 Acc: 83 %
# Epoch [2/100], Iter [1930/3189] Loss: 0.2916 Acc: 83 %
# Epoch [2/100], Iter [1940/3189] Loss: 0.3344 Acc: 83 %
# Epoch [2/100], Iter [1950/3189] Loss: 0.2950 Acc: 83 %
# Epoch [2/100], Iter [1960/3189] Loss: 0.3547 Acc: 83 %
# Epoch [2/100], Iter [1970/3189] Loss: 0.3243 Acc: 83 %
# Epoch [2/100], Iter [1980/3189] Loss: 0.3104 Acc: 83 %
# Epoch [2/100], Iter [1990/3189] Loss: 0.3076 Acc: 83 %
# Epoch [2/100], Iter [2000/3189] Loss: 0.3508 Acc: 83 %
# Epoch [2/100], Iter [2010/3189] Loss: 0.3465 Acc: 83 %
# Epoch [2/100], Iter [2020/3189] Loss: 0.3374 Acc: 83 %
# Epoch [2/100], Iter [2030/3189] Loss: 0.3211 Acc: 83 %
# Epoch [2/100], Iter [2040/3189] Loss: 0.3208 Acc: 83 %
# Epoch [2/100], Iter [2050/3189] Loss: 0.3389 Acc: 83 %
# Epoch [2/100], Iter [2060/3189] Loss: 0.3591 Acc: 83 %
# Epoch [2/100], Iter [2070/3189] Loss: 0.3216 Acc: 83 %
# Epoch [2/100], Iter [2080/3189] Loss: 0.3566 Acc: 83 %
# Epoch [2/100], Iter [2090/3189] Loss: 0.2870 Acc: 83 %
# Epoch [2/100], Iter [2100/3189] Loss: 0.3210 Acc: 83 %
# Epoch [2/100], Iter [2110/3189] Loss: 0.3416 Acc: 83 %
# Epoch [2/100], Iter [2120/3189] Loss: 0.3405 Acc: 83 %
# Epoch [2/100], Iter [2130/3189] Loss: 0.2995 Acc: 83 %
# Epoch [2/100], Iter [2140/3189] Loss: 0.3560 Acc: 83 %
# Epoch [2/100], Iter [2150/3189] Loss: 0.3541 Acc: 83 %
# Epoch [2/100], Iter [2160/3189] Loss: 0.3548 Acc: 83 %
# Epoch [2/100], Iter [2170/3189] Loss: 0.3096 Acc: 83 %
# Epoch [2/100], Iter [2180/3189] Loss: 0.3272 Acc: 83 %
# Epoch [2/100], Iter [2190/3189] Loss: 0.3198 Acc: 83 %
# Epoch [2/100], Iter [2200/3189] Loss: 0.3344 Acc: 83 %
# Epoch [2/100], Iter [2210/3189] Loss: 0.3168 Acc: 83 %
# Epoch [2/100], Iter [2220/3189] Loss: 0.3482 Acc: 83 %
# Epoch [2/100], Iter [2230/3189] Loss: 0.3531 Acc: 83 %
# Epoch [2/100], Iter [2240/3189] Loss: 0.3110 Acc: 83 %
# Epoch [2/100], Iter [2250/3189] Loss: 0.3258 Acc: 83 %
# Epoch [2/100], Iter [2260/3189] Loss: 0.3173 Acc: 83 %
# Epoch [2/100], Iter [2270/3189] Loss: 0.2837 Acc: 83 %
# Epoch [2/100], Iter [2280/3189] Loss: 0.3105 Acc: 83 %
# Epoch [2/100], Iter [2290/3189] Loss: 0.2846 Acc: 83 %
# Epoch [2/100], Iter [2300/3189] Loss: 0.3229 Acc: 83 %
# Epoch [2/100], Iter [2310/3189] Loss: 0.3011 Acc: 83 %
# Epoch [2/100], Iter [2320/3189] Loss: 0.3265 Acc: 83 %
# Epoch [2/100], Iter [2330/3189] Loss: 0.3541 Acc: 83 %
# Epoch [2/100], Iter [2340/3189] Loss: 0.3471 Acc: 83 %
# Epoch [2/100], Iter [2350/3189] Loss: 0.3224 Acc: 83 %
# Epoch [2/100], Iter [2360/3189] Loss: 0.3025 Acc: 83 %
# Epoch [2/100], Iter [2370/3189] Loss: 0.3017 Acc: 83 %
# Epoch [2/100], Iter [2380/3189] Loss: 0.2871 Acc: 83 %
# Epoch [2/100], Iter [2390/3189] Loss: 0.3114 Acc: 83 %
# Epoch [2/100], Iter [2400/3189] Loss: 0.3333 Acc: 83 %
# Epoch [2/100], Iter [2410/3189] Loss: 0.3098 Acc: 83 %
# Epoch [2/100], Iter [2420/3189] Loss: 0.3520 Acc: 83 %
# Epoch [2/100], Iter [2430/3189] Loss: 0.3313 Acc: 83 %
# Epoch [2/100], Iter [2440/3189] Loss: 0.3525 Acc: 83 %
# Epoch [2/100], Iter [2450/3189] Loss: 0.3680 Acc: 83 %
# Epoch [2/100], Iter [2460/3189] Loss: 0.3482 Acc: 83 %
# Epoch [2/100], Iter [2470/3189] Loss: 0.3367 Acc: 83 %
# Epoch [2/100], Iter [2480/3189] Loss: 0.3474 Acc: 83 %
# Epoch [2/100], Iter [2490/3189] Loss: 0.3431 Acc: 83 %
# Epoch [2/100], Iter [2500/3189] Loss: 0.3100 Acc: 83 %
# Epoch [2/100], Iter [2510/3189] Loss: 0.3148 Acc: 83 %
# Epoch [2/100], Iter [2520/3189] Loss: 0.3012 Acc: 83 %
# Epoch [2/100], Iter [2530/3189] Loss: 0.2816 Acc: 83 %
# Epoch [2/100], Iter [2540/3189] Loss: 0.2922 Acc: 83 %
# Epoch [2/100], Iter [2550/3189] Loss: 0.3108 Acc: 83 %
# Epoch [2/100], Iter [2560/3189] Loss: 0.3098 Acc: 83 %
# Epoch [2/100], Iter [2570/3189] Loss: 0.3132 Acc: 84 %
# Epoch [2/100], Iter [2580/3189] Loss: 0.3201 Acc: 84 %
# Epoch [2/100], Iter [2590/3189] Loss: 0.3073 Acc: 84 %
# Epoch [2/100], Iter [2600/3189] Loss: 0.3060 Acc: 84 %
# Epoch [2/100], Iter [2610/3189] Loss: 0.3237 Acc: 84 %
# Epoch [2/100], Iter [2620/3189] Loss: 0.3242 Acc: 84 %
# Epoch [2/100], Iter [2630/3189] Loss: 0.3412 Acc: 84 %
# Epoch [2/100], Iter [2640/3189] Loss: 0.3181 Acc: 84 %
# Epoch [2/100], Iter [2650/3189] Loss: 0.3232 Acc: 84 %
# Epoch [2/100], Iter [2660/3189] Loss: 0.3547 Acc: 84 %
# Epoch [2/100], Iter [2670/3189] Loss: 0.3207 Acc: 84 %
# Epoch [2/100], Iter [2680/3189] Loss: 0.2897 Acc: 84 %
# Epoch [2/100], Iter [2690/3189] Loss: 0.3274 Acc: 84 %
# Epoch [2/100], Iter [2700/3189] Loss: 0.3670 Acc: 84 %
# Epoch [2/100], Iter [2710/3189] Loss: 0.3373 Acc: 84 %
# Epoch [2/100], Iter [2720/3189] Loss: 0.3275 Acc: 84 %
# Epoch [2/100], Iter [2730/3189] Loss: 0.3163 Acc: 84 %
# Epoch [2/100], Iter [2740/3189] Loss: 0.3253 Acc: 84 %
# Epoch [2/100], Iter [2750/3189] Loss: 0.3138 Acc: 84 %
# Epoch [2/100], Iter [2760/3189] Loss: 0.3257 Acc: 84 %
# Epoch [2/100], Iter [2770/3189] Loss: 0.3051 Acc: 84 %
# Epoch [2/100], Iter [2780/3189] Loss: 0.3429 Acc: 84 %
# Epoch [2/100], Iter [2790/3189] Loss: 0.2991 Acc: 84 %
# Epoch [2/100], Iter [2800/3189] Loss: 0.3129 Acc: 84 %
# Epoch [2/100], Iter [2810/3189] Loss: 0.3281 Acc: 84 %
# Epoch [2/100], Iter [2820/3189] Loss: 0.3094 Acc: 84 %
# Epoch [2/100], Iter [2830/3189] Loss: 0.3106 Acc: 84 %
# Epoch [2/100], Iter [2840/3189] Loss: 0.3212 Acc: 84 %
# Epoch [2/100], Iter [2850/3189] Loss: 0.3037 Acc: 84 %
# Epoch [2/100], Iter [2860/3189] Loss: 0.3225 Acc: 84 %
# Epoch [2/100], Iter [2870/3189] Loss: 0.3234 Acc: 84 %
# Epoch [2/100], Iter [2880/3189] Loss: 0.3460 Acc: 84 %
# Epoch [2/100], Iter [2890/3189] Loss: 0.2855 Acc: 84 %
# Epoch [2/100], Iter [2900/3189] Loss: 0.3328 Acc: 84 %
# Epoch [2/100], Iter [2910/3189] Loss: 0.3018 Acc: 84 %
# Epoch [2/100], Iter [2920/3189] Loss: 0.3713 Acc: 84 %
# Epoch [2/100], Iter [2930/3189] Loss: 0.3166 Acc: 84 %
# Epoch [2/100], Iter [2940/3189] Loss: 0.3550 Acc: 84 %
# Epoch [2/100], Iter [2950/3189] Loss: 0.3161 Acc: 84 %
# Epoch [2/100], Iter [2960/3189] Loss: 0.3133 Acc: 84 %
# Epoch [2/100], Iter [2970/3189] Loss: 0.3020 Acc: 84 %
# Epoch [2/100], Iter [2980/3189] Loss: 0.3045 Acc: 84 %
# Epoch [2/100], Iter [2990/3189] Loss: 0.2687 Acc: 84 %
# Epoch [2/100], Iter [3000/3189] Loss: 0.3201 Acc: 84 %
# Epoch [2/100], Iter [3010/3189] Loss: 0.3080 Acc: 84 %
# Epoch [2/100], Iter [3020/3189] Loss: 0.3028 Acc: 84 %
# Epoch [2/100], Iter [3030/3189] Loss: 0.3103 Acc: 84 %
# Epoch [2/100], Iter [3040/3189] Loss: 0.2832 Acc: 84 %
# Epoch [2/100], Iter [3050/3189] Loss: 0.3340 Acc: 84 %
# Epoch [2/100], Iter [3060/3189] Loss: 0.3329 Acc: 84 %
# Epoch [2/100], Iter [3070/3189] Loss: 0.4136 Acc: 84 %
# Epoch [2/100], Iter [3080/3189] Loss: 0.3383 Acc: 84 %
# Epoch [2/100], Iter [3090/3189] Loss: 0.3484 Acc: 84 %
# Epoch [2/100], Iter [3100/3189] Loss: 0.3566 Acc: 84 %
# Epoch [2/100], Iter [3110/3189] Loss: 0.3300 Acc: 84 %
# Epoch [2/100], Iter [3120/3189] Loss: 0.3192 Acc: 84 %
# Epoch [2/100], Iter [3130/3189] Loss: 0.3405 Acc: 84 %
# Epoch [2/100], Iter [3140/3189] Loss: 0.3657 Acc: 84 %
# Epoch [2/100], Iter [3150/3189] Loss: 0.3121 Acc: 84 %
# Epoch [2/100], Iter [3160/3189] Loss: 0.3016 Acc: 84 %
# Epoch [2/100], Iter [3170/3189] Loss: 0.3744 Acc: 84 %
# Epoch [2/100], Iter [3180/3189] Loss: 0.3927 Acc: 84 %
# Accuracy of the model on the aki negative sequence: 85 %
# Accuracy of the model on the aki positive sequence: 76 %
# EarlyStopping counter: 1 out of 10
# Epoch [3/100], Iter [10/3189] Loss: 0.3006 Acc: 83 %
# Epoch [3/100], Iter [20/3189] Loss: 0.3230 Acc: 84 %
# Epoch [3/100], Iter [30/3189] Loss: 0.3149 Acc: 84 %
# Epoch [3/100], Iter [40/3189] Loss: 0.3223 Acc: 84 %
# Epoch [3/100], Iter [50/3189] Loss: 0.2695 Acc: 85 %
# Epoch [3/100], Iter [60/3189] Loss: 0.3309 Acc: 85 %
# Epoch [3/100], Iter [70/3189] Loss: 0.3261 Acc: 85 %
# Epoch [3/100], Iter [80/3189] Loss: 0.3055 Acc: 84 %
# Epoch [3/100], Iter [90/3189] Loss: 0.2661 Acc: 84 %
# Epoch [3/100], Iter [100/3189] Loss: 0.2945 Acc: 85 %
# Epoch [3/100], Iter [110/3189] Loss: 0.3280 Acc: 85 %
# Epoch [3/100], Iter [120/3189] Loss: 0.3064 Acc: 85 %
# Epoch [3/100], Iter [130/3189] Loss: 0.3654 Acc: 85 %
# Epoch [3/100], Iter [140/3189] Loss: 0.3466 Acc: 85 %
# Epoch [3/100], Iter [150/3189] Loss: 0.3322 Acc: 84 %
# Epoch [3/100], Iter [160/3189] Loss: 0.3132 Acc: 84 %
# Epoch [3/100], Iter [170/3189] Loss: 0.3454 Acc: 84 %
# Epoch [3/100], Iter [180/3189] Loss: 0.3055 Acc: 84 %
# Epoch [3/100], Iter [190/3189] Loss: 0.3045 Acc: 84 %
# Epoch [3/100], Iter [200/3189] Loss: 0.3425 Acc: 84 %
# Epoch [3/100], Iter [210/3189] Loss: 0.3546 Acc: 84 %
# Epoch [3/100], Iter [220/3189] Loss: 0.3404 Acc: 84 %
# Epoch [3/100], Iter [230/3189] Loss: 0.4093 Acc: 84 %
# Epoch [3/100], Iter [240/3189] Loss: 0.3531 Acc: 84 %
# Epoch [3/100], Iter [250/3189] Loss: 0.3432 Acc: 84 %
# Epoch [3/100], Iter [260/3189] Loss: 0.3333 Acc: 84 %
# Epoch [3/100], Iter [270/3189] Loss: 0.3622 Acc: 84 %
# Epoch [3/100], Iter [280/3189] Loss: 0.3332 Acc: 84 %
# Epoch [3/100], Iter [290/3189] Loss: 0.3308 Acc: 84 %
# Epoch [3/100], Iter [300/3189] Loss: 0.3792 Acc: 84 %
# Epoch [3/100], Iter [310/3189] Loss: 0.3478 Acc: 84 %
# Epoch [3/100], Iter [320/3189] Loss: 0.3315 Acc: 84 %
# Epoch [3/100], Iter [330/3189] Loss: 0.3329 Acc: 84 %
# Epoch [3/100], Iter [340/3189] Loss: 0.3277 Acc: 84 %
# Epoch [3/100], Iter [350/3189] Loss: 0.3344 Acc: 84 %
# Epoch [3/100], Iter [360/3189] Loss: 0.3523 Acc: 84 %
# Epoch [3/100], Iter [370/3189] Loss: 0.3494 Acc: 84 %
# Epoch [3/100], Iter [380/3189] Loss: 0.3074 Acc: 84 %
# Epoch [3/100], Iter [390/3189] Loss: 0.3988 Acc: 84 %
# Epoch [3/100], Iter [400/3189] Loss: 0.2981 Acc: 84 %
# Epoch [3/100], Iter [410/3189] Loss: 0.3496 Acc: 84 %
# Epoch [3/100], Iter [420/3189] Loss: 0.2819 Acc: 84 %
# Epoch [3/100], Iter [430/3189] Loss: 0.3489 Acc: 84 %
# Epoch [3/100], Iter [440/3189] Loss: 0.3191 Acc: 84 %
# Epoch [3/100], Iter [450/3189] Loss: 0.4225 Acc: 84 %
# Epoch [3/100], Iter [460/3189] Loss: 0.4068 Acc: 84 %
# Epoch [3/100], Iter [470/3189] Loss: 0.3165 Acc: 84 %
# Epoch [3/100], Iter [480/3189] Loss: 0.3135 Acc: 84 %
# Epoch [3/100], Iter [490/3189] Loss: 0.3452 Acc: 84 %
# Epoch [3/100], Iter [500/3189] Loss: 0.3021 Acc: 84 %
# Epoch [3/100], Iter [510/3189] Loss: 0.3284 Acc: 84 %
# Epoch [3/100], Iter [520/3189] Loss: 0.2988 Acc: 84 %
# Epoch [3/100], Iter [530/3189] Loss: 0.2768 Acc: 84 %
# Epoch [3/100], Iter [540/3189] Loss: 0.3417 Acc: 84 %
# Epoch [3/100], Iter [550/3189] Loss: 0.3176 Acc: 84 %
# Epoch [3/100], Iter [560/3189] Loss: 0.3134 Acc: 84 %
# Epoch [3/100], Iter [570/3189] Loss: 0.3007 Acc: 84 %
# Epoch [3/100], Iter [580/3189] Loss: 0.3573 Acc: 84 %
# Epoch [3/100], Iter [590/3189] Loss: 0.3170 Acc: 84 %
# Epoch [3/100], Iter [600/3189] Loss: 0.2999 Acc: 84 %
# Epoch [3/100], Iter [610/3189] Loss: 0.2735 Acc: 84 %
# Epoch [3/100], Iter [620/3189] Loss: 0.3523 Acc: 84 %
# Epoch [3/100], Iter [630/3189] Loss: 0.3764 Acc: 84 %
# Epoch [3/100], Iter [640/3189] Loss: 0.3449 Acc: 84 %
# Epoch [3/100], Iter [650/3189] Loss: 0.3231 Acc: 84 %
# Epoch [3/100], Iter [660/3189] Loss: 0.2641 Acc: 84 %
# Epoch [3/100], Iter [670/3189] Loss: 0.3236 Acc: 84 %
# Epoch [3/100], Iter [680/3189] Loss: 0.3029 Acc: 84 %
# Epoch [3/100], Iter [690/3189] Loss: 0.3074 Acc: 84 %
# Epoch [3/100], Iter [700/3189] Loss: 0.3389 Acc: 84 %
# Epoch [3/100], Iter [710/3189] Loss: 0.3495 Acc: 84 %
# Epoch [3/100], Iter [720/3189] Loss: 0.3260 Acc: 84 %
# Epoch [3/100], Iter [730/3189] Loss: 0.3479 Acc: 84 %
# Epoch [3/100], Iter [740/3189] Loss: 0.3210 Acc: 84 %
# Epoch [3/100], Iter [750/3189] Loss: 0.3062 Acc: 84 %
# Epoch [3/100], Iter [760/3189] Loss: 0.3141 Acc: 84 %
# Epoch [3/100], Iter [770/3189] Loss: 0.2941 Acc: 84 %
# Epoch [3/100], Iter [780/3189] Loss: 0.3230 Acc: 84 %
# Epoch [3/100], Iter [790/3189] Loss: 0.3725 Acc: 84 %
# Epoch [3/100], Iter [800/3189] Loss: 0.3390 Acc: 84 %
# Epoch [3/100], Iter [810/3189] Loss: 0.3852 Acc: 84 %
# Epoch [3/100], Iter [820/3189] Loss: 0.3837 Acc: 84 %
# Epoch [3/100], Iter [830/3189] Loss: 0.3600 Acc: 84 %
# Epoch [3/100], Iter [840/3189] Loss: 0.3489 Acc: 84 %
# Epoch [3/100], Iter [850/3189] Loss: 0.3343 Acc: 84 %
# Epoch [3/100], Iter [860/3189] Loss: 0.3167 Acc: 84 %
# Epoch [3/100], Iter [870/3189] Loss: 0.3684 Acc: 84 %
# Epoch [3/100], Iter [880/3189] Loss: 0.3099 Acc: 84 %
# Epoch [3/100], Iter [890/3189] Loss: 0.3251 Acc: 84 %
# Epoch [3/100], Iter [900/3189] Loss: 0.3079 Acc: 84 %
# Epoch [3/100], Iter [910/3189] Loss: 0.2686 Acc: 84 %
# Epoch [3/100], Iter [920/3189] Loss: 0.3442 Acc: 84 %
# Epoch [3/100], Iter [930/3189] Loss: 0.3306 Acc: 84 %
# Epoch [3/100], Iter [940/3189] Loss: 0.3149 Acc: 84 %
# Epoch [3/100], Iter [950/3189] Loss: 0.3610 Acc: 84 %
# Epoch [3/100], Iter [960/3189] Loss: 0.2929 Acc: 84 %
# Epoch [3/100], Iter [970/3189] Loss: 0.3082 Acc: 84 %
# Epoch [3/100], Iter [980/3189] Loss: 0.3401 Acc: 84 %
# Epoch [3/100], Iter [990/3189] Loss: 0.3158 Acc: 84 %
# Epoch [3/100], Iter [1000/3189] Loss: 0.3035 Acc: 84 %
# Epoch [3/100], Iter [1010/3189] Loss: 0.3209 Acc: 84 %
# Epoch [3/100], Iter [1020/3189] Loss: 0.3485 Acc: 84 %
# Epoch [3/100], Iter [1030/3189] Loss: 0.3168 Acc: 84 %
# Epoch [3/100], Iter [1040/3189] Loss: 0.2997 Acc: 84 %
# Epoch [3/100], Iter [1050/3189] Loss: 0.3160 Acc: 84 %
# Epoch [3/100], Iter [1060/3189] Loss: 0.3167 Acc: 84 %
# Epoch [3/100], Iter [1070/3189] Loss: 0.3246 Acc: 84 %
# Epoch [3/100], Iter [1080/3189] Loss: 0.3079 Acc: 84 %
# Epoch [3/100], Iter [1090/3189] Loss: 0.3164 Acc: 84 %
# Epoch [3/100], Iter [1100/3189] Loss: 0.2985 Acc: 84 %
# Epoch [3/100], Iter [1110/3189] Loss: 0.3174 Acc: 84 %
# Epoch [3/100], Iter [1120/3189] Loss: 0.3065 Acc: 84 %
# Epoch [3/100], Iter [1130/3189] Loss: 0.2962 Acc: 84 %
# Epoch [3/100], Iter [1140/3189] Loss: 0.3247 Acc: 84 %
# Epoch [3/100], Iter [1150/3189] Loss: 0.3467 Acc: 84 %
# Epoch [3/100], Iter [1160/3189] Loss: 0.3182 Acc: 84 %
# Epoch [3/100], Iter [1170/3189] Loss: 0.3593 Acc: 84 %
# Epoch [3/100], Iter [1180/3189] Loss: 0.3232 Acc: 84 %
# Epoch [3/100], Iter [1190/3189] Loss: 0.2939 Acc: 84 %
# Epoch [3/100], Iter [1200/3189] Loss: 0.3371 Acc: 84 %
# Epoch [3/100], Iter [1210/3189] Loss: 0.3829 Acc: 84 %
# Epoch [3/100], Iter [1220/3189] Loss: 0.3204 Acc: 84 %
# Epoch [3/100], Iter [1230/3189] Loss: 0.3391 Acc: 84 %
# Epoch [3/100], Iter [1240/3189] Loss: 0.3164 Acc: 84 %
# Epoch [3/100], Iter [1250/3189] Loss: 0.2804 Acc: 84 %
# Epoch [3/100], Iter [1260/3189] Loss: 0.3084 Acc: 84 %
# Epoch [3/100], Iter [1270/3189] Loss: 0.3208 Acc: 84 %
# Epoch [3/100], Iter [1280/3189] Loss: 0.3183 Acc: 84 %
# Epoch [3/100], Iter [1290/3189] Loss: 0.2940 Acc: 84 %
# Epoch [3/100], Iter [1300/3189] Loss: 0.3005 Acc: 84 %
# Epoch [3/100], Iter [1310/3189] Loss: 0.2963 Acc: 84 %
# Epoch [3/100], Iter [1320/3189] Loss: 0.3002 Acc: 84 %
# Epoch [3/100], Iter [1330/3189] Loss: 0.3701 Acc: 84 %
# Epoch [3/100], Iter [1340/3189] Loss: 0.2986 Acc: 84 %
# Epoch [3/100], Iter [1350/3189] Loss: 0.3346 Acc: 84 %
# Epoch [3/100], Iter [1360/3189] Loss: 0.2894 Acc: 84 %
# Epoch [3/100], Iter [1370/3189] Loss: 0.3171 Acc: 84 %
# Epoch [3/100], Iter [1380/3189] Loss: 0.3147 Acc: 84 %
# Epoch [3/100], Iter [1390/3189] Loss: 0.3058 Acc: 84 %
# Epoch [3/100], Iter [1400/3189] Loss: 0.2957 Acc: 84 %
# Epoch [3/100], Iter [1410/3189] Loss: 0.3284 Acc: 84 %
# Epoch [3/100], Iter [1420/3189] Loss: 0.3254 Acc: 84 %
# Epoch [3/100], Iter [1430/3189] Loss: 0.3181 Acc: 84 %
# Epoch [3/100], Iter [1440/3189] Loss: 0.3804 Acc: 85 %
# Epoch [3/100], Iter [1450/3189] Loss: 0.3829 Acc: 84 %
# Epoch [3/100], Iter [1460/3189] Loss: 0.3500 Acc: 84 %
# Epoch [3/100], Iter [1470/3189] Loss: 0.3062 Acc: 84 %
# Epoch [3/100], Iter [1480/3189] Loss: 0.3022 Acc: 84 %
# Epoch [3/100], Iter [1490/3189] Loss: 0.3523 Acc: 84 %
# Epoch [3/100], Iter [1500/3189] Loss: 0.3341 Acc: 84 %
# Epoch [3/100], Iter [1510/3189] Loss: 0.2977 Acc: 84 %
# Epoch [3/100], Iter [1520/3189] Loss: 0.3590 Acc: 84 %
# Epoch [3/100], Iter [1530/3189] Loss: 0.3243 Acc: 84 %
# Epoch [3/100], Iter [1540/3189] Loss: 0.3012 Acc: 84 %
# Epoch [3/100], Iter [1550/3189] Loss: 0.3330 Acc: 84 %
# Epoch [3/100], Iter [1560/3189] Loss: 0.2931 Acc: 84 %
# Epoch [3/100], Iter [1570/3189] Loss: 0.3172 Acc: 84 %
# Epoch [3/100], Iter [1580/3189] Loss: 0.3093 Acc: 84 %
# Epoch [3/100], Iter [1590/3189] Loss: 0.2980 Acc: 84 %
# Epoch [3/100], Iter [1600/3189] Loss: 0.2820 Acc: 84 %
# Epoch [3/100], Iter [1610/3189] Loss: 0.3097 Acc: 84 %
# Epoch [3/100], Iter [1620/3189] Loss: 0.3137 Acc: 85 %
# Epoch [3/100], Iter [1630/3189] Loss: 0.3158 Acc: 85 %
# Epoch [3/100], Iter [1640/3189] Loss: 0.3380 Acc: 85 %
# Epoch [3/100], Iter [1650/3189] Loss: 0.3356 Acc: 85 %
# Epoch [3/100], Iter [1660/3189] Loss: 0.3174 Acc: 84 %
# Epoch [3/100], Iter [1670/3189] Loss: 0.3064 Acc: 84 %
# Epoch [3/100], Iter [1680/3189] Loss: 0.3096 Acc: 85 %
# Epoch [3/100], Iter [1690/3189] Loss: 0.2615 Acc: 85 %
# Epoch [3/100], Iter [1700/3189] Loss: 0.3406 Acc: 85 %
# Epoch [3/100], Iter [1710/3189] Loss: 0.3169 Acc: 85 %
# Epoch [3/100], Iter [1720/3189] Loss: 0.3156 Acc: 85 %
# Epoch [3/100], Iter [1730/3189] Loss: 0.3191 Acc: 84 %
# Epoch [3/100], Iter [1740/3189] Loss: 0.3161 Acc: 84 %
# Epoch [3/100], Iter [1750/3189] Loss: 0.3347 Acc: 84 %
# Epoch [3/100], Iter [1760/3189] Loss: 0.3679 Acc: 85 %
# Epoch [3/100], Iter [1770/3189] Loss: 0.3010 Acc: 85 %
# Epoch [3/100], Iter [1780/3189] Loss: 0.3255 Acc: 85 %
# Epoch [3/100], Iter [1790/3189] Loss: 0.3236 Acc: 85 %
# Epoch [3/100], Iter [1800/3189] Loss: 0.2916 Acc: 85 %
# Epoch [3/100], Iter [1810/3189] Loss: 0.3356 Acc: 85 %
# Epoch [3/100], Iter [1820/3189] Loss: 0.2728 Acc: 85 %
# Epoch [3/100], Iter [1830/3189] Loss: 0.2988 Acc: 85 %
# Epoch [3/100], Iter [1840/3189] Loss: 0.3302 Acc: 85 %
# Epoch [3/100], Iter [1850/3189] Loss: 0.3065 Acc: 85 %
# Epoch [3/100], Iter [1860/3189] Loss: 0.3164 Acc: 85 %
# Epoch [3/100], Iter [1870/3189] Loss: 0.3029 Acc: 85 %
# Epoch [3/100], Iter [1880/3189] Loss: 0.3082 Acc: 85 %
# Epoch [3/100], Iter [1890/3189] Loss: 0.2902 Acc: 85 %
# Epoch [3/100], Iter [1900/3189] Loss: 0.2788 Acc: 85 %
# Epoch [3/100], Iter [1910/3189] Loss: 0.2964 Acc: 85 %
# Epoch [3/100], Iter [1920/3189] Loss: 0.3135 Acc: 85 %
# Epoch [3/100], Iter [1930/3189] Loss: 0.3045 Acc: 85 %
# Epoch [3/100], Iter [1940/3189] Loss: 0.2756 Acc: 85 %
# Epoch [3/100], Iter [1950/3189] Loss: 0.2992 Acc: 85 %
# Epoch [3/100], Iter [1960/3189] Loss: 0.3594 Acc: 85 %
# Epoch [3/100], Iter [1970/3189] Loss: 0.2905 Acc: 85 %
# Epoch [3/100], Iter [1980/3189] Loss: 0.2941 Acc: 85 %
# Epoch [3/100], Iter [1990/3189] Loss: 0.3142 Acc: 85 %
# Epoch [3/100], Iter [2000/3189] Loss: 0.3840 Acc: 85 %
# Epoch [3/100], Iter [2010/3189] Loss: 0.3058 Acc: 85 %
# Epoch [3/100], Iter [2020/3189] Loss: 0.3482 Acc: 85 %
# Epoch [3/100], Iter [2030/3189] Loss: 0.3694 Acc: 85 %
# Epoch [3/100], Iter [2040/3189] Loss: 0.3403 Acc: 85 %
# Epoch [3/100], Iter [2050/3189] Loss: 0.3211 Acc: 85 %
# Epoch [3/100], Iter [2060/3189] Loss: 0.3135 Acc: 85 %
# Epoch [3/100], Iter [2070/3189] Loss: 0.3003 Acc: 85 %
# Epoch [3/100], Iter [2080/3189] Loss: 0.2996 Acc: 85 %
# Epoch [3/100], Iter [2090/3189] Loss: 0.2973 Acc: 85 %
# Epoch [3/100], Iter [2100/3189] Loss: 0.3017 Acc: 85 %
# Epoch [3/100], Iter [2110/3189] Loss: 0.3232 Acc: 85 %
# Epoch [3/100], Iter [2120/3189] Loss: 0.3040 Acc: 85 %
# Epoch [3/100], Iter [2130/3189] Loss: 0.2787 Acc: 85 %
# Epoch [3/100], Iter [2140/3189] Loss: 0.2606 Acc: 85 %
# Epoch [3/100], Iter [2150/3189] Loss: 0.3148 Acc: 85 %
# Epoch [3/100], Iter [2160/3189] Loss: 0.3006 Acc: 85 %
# Epoch [3/100], Iter [2170/3189] Loss: 0.2919 Acc: 85 %
# Epoch [3/100], Iter [2180/3189] Loss: 0.2919 Acc: 85 %
# Epoch [3/100], Iter [2190/3189] Loss: 0.3103 Acc: 85 %
# Epoch [3/100], Iter [2200/3189] Loss: 0.2770 Acc: 85 %
# Epoch [3/100], Iter [2210/3189] Loss: 0.3043 Acc: 85 %
# Epoch [3/100], Iter [2220/3189] Loss: 0.3152 Acc: 85 %
# Epoch [3/100], Iter [2230/3189] Loss: 0.3226 Acc: 85 %
# Epoch [3/100], Iter [2240/3189] Loss: 0.3226 Acc: 85 %
# Epoch [3/100], Iter [2250/3189] Loss: 0.3620 Acc: 85 %
# Epoch [3/100], Iter [2260/3189] Loss: 0.3403 Acc: 85 %
# Epoch [3/100], Iter [2270/3189] Loss: 0.3301 Acc: 85 %
# Epoch [3/100], Iter [2280/3189] Loss: 0.3261 Acc: 85 %
# Epoch [3/100], Iter [2290/3189] Loss: 0.3325 Acc: 85 %
# Epoch [3/100], Iter [2300/3189] Loss: 0.2803 Acc: 85 %
# Epoch [3/100], Iter [2310/3189] Loss: 0.3408 Acc: 85 %
# Epoch [3/100], Iter [2320/3189] Loss: 0.3554 Acc: 85 %
# Epoch [3/100], Iter [2330/3189] Loss: 0.3404 Acc: 85 %
# Epoch [3/100], Iter [2340/3189] Loss: 0.3345 Acc: 85 %
# Epoch [3/100], Iter [2350/3189] Loss: 0.3350 Acc: 85 %
# Epoch [3/100], Iter [2360/3189] Loss: 0.2971 Acc: 85 %
# ...
# Epoch [16/100], Iter [360/3189] Loss: 0.2639 Acc: 87 %
# Epoch [16/100], Iter [370/3189] Loss: 0.2874 Acc: 87 %
# Epoch [16/100], Iter [380/3189] Loss: 0.2834 Acc: 87 %
# Epoch [16/100], Iter [390/3189] Loss: 0.2970 Acc: 87 %
# Epoch [16/100], Iter [400/3189] Loss: 0.2685 Acc: 87 %
# Epoch [16/100], Iter [410/3189] Loss: 0.3113 Acc: 87 %
# Epoch [16/100], Iter [420/3189] Loss: 0.2685 Acc: 87 %
# Epoch [16/100], Iter [430/3189] Loss: 0.2873 Acc: 87 %
# Epoch [16/100], Iter [440/3189] Loss: 0.2859 Acc: 87 %
# Epoch [16/100], Iter [450/3189] Loss: 0.3096 Acc: 87 %
# Epoch [16/100], Iter [460/3189] Loss: 0.2937 Acc: 87 %
# Epoch [16/100], Iter [470/3189] Loss: 0.2816 Acc: 87 %
# Epoch [16/100], Iter [480/3189] Loss: 0.2742 Acc: 87 %
# Epoch [16/100], Iter [490/3189] Loss: 0.2508 Acc: 87 %
# Epoch [16/100], Iter [500/3189] Loss: 0.3056 Acc: 87 %
# Epoch [16/100], Iter [510/3189] Loss: 0.2784 Acc: 87 %
# Epoch [16/100], Iter [520/3189] Loss: 0.2811 Acc: 87 %
# Epoch [16/100], Iter [530/3189] Loss: 0.2842 Acc: 87 %
# Epoch [16/100], Iter [540/3189] Loss: 0.2748 Acc: 87 %
# Epoch [16/100], Iter [550/3189] Loss: 0.3049 Acc: 87 %
# Epoch [16/100], Iter [560/3189] Loss: 0.2842 Acc: 87 %
# Epoch [16/100], Iter [570/3189] Loss: 0.2741 Acc: 87 %
# Epoch [16/100], Iter [580/3189] Loss: 0.2613 Acc: 87 %
# Epoch [16/100], Iter [590/3189] Loss: 0.3097 Acc: 87 %
# Epoch [16/100], Iter [600/3189] Loss: 0.2829 Acc: 87 %
# Epoch [16/100], Iter [610/3189] Loss: 0.2772 Acc: 87 %
# Epoch [16/100], Iter [620/3189] Loss: 0.2774 Acc: 87 %
# Epoch [16/100], Iter [630/3189] Loss: 0.2986 Acc: 87 %
# Epoch [16/100], Iter [640/3189] Loss: 0.2903 Acc: 87 %
# Epoch [16/100], Iter [650/3189] Loss: 0.3028 Acc: 87 %
# Epoch [16/100], Iter [660/3189] Loss: 0.2911 Acc: 87 %
# Epoch [16/100], Iter [670/3189] Loss: 0.2673 Acc: 87 %
# Epoch [16/100], Iter [680/3189] Loss: 0.2735 Acc: 87 %
# Epoch [16/100], Iter [690/3189] Loss: 0.2628 Acc: 87 %
# Epoch [16/100], Iter [700/3189] Loss: 0.3011 Acc: 87 %
# Epoch [16/100], Iter [710/3189] Loss: 0.2693 Acc: 87 %
# Epoch [16/100], Iter [720/3189] Loss: 0.2893 Acc: 87 %
# Epoch [16/100], Iter [730/3189] Loss: 0.2571 Acc: 87 %
# Epoch [16/100], Iter [740/3189] Loss: 0.3079 Acc: 87 %
# Epoch [16/100], Iter [750/3189] Loss: 0.2889 Acc: 87 %
# Epoch [16/100], Iter [760/3189] Loss: 0.3058 Acc: 87 %
# Epoch [16/100], Iter [770/3189] Loss: 0.2750 Acc: 87 %
# Epoch [16/100], Iter [780/3189] Loss: 0.2803 Acc: 87 %
# Epoch [16/100], Iter [790/3189] Loss: 0.2909 Acc: 87 %
# Epoch [16/100], Iter [800/3189] Loss: 0.2782 Acc: 87 %
# Epoch [16/100], Iter [810/3189] Loss: 0.2806 Acc: 87 %
# Epoch [16/100], Iter [820/3189] Loss: 0.2875 Acc: 87 %
# Epoch [16/100], Iter [830/3189] Loss: 0.2728 Acc: 87 %
# Epoch [16/100], Iter [840/3189] Loss: 0.2805 Acc: 87 %
# Epoch [16/100], Iter [850/3189] Loss: 0.2893 Acc: 87 %
# Epoch [16/100], Iter [860/3189] Loss: 0.3028 Acc: 87 %
# Epoch [16/100], Iter [870/3189] Loss: 0.2805 Acc: 87 %
# Epoch [16/100], Iter [880/3189] Loss: 0.3205 Acc: 87 %
# Epoch [16/100], Iter [890/3189] Loss: 0.2719 Acc: 87 %
# Epoch [16/100], Iter [900/3189] Loss: 0.2831 Acc: 87 %
# Epoch [16/100], Iter [910/3189] Loss: 0.3135 Acc: 87 %
# Epoch [16/100], Iter [920/3189] Loss: 0.2964 Acc: 87 %
# Epoch [16/100], Iter [930/3189] Loss: 0.3024 Acc: 87 %
# Epoch [16/100], Iter [940/3189] Loss: 0.2772 Acc: 87 %
# Epoch [16/100], Iter [950/3189] Loss: 0.2819 Acc: 87 %
# Epoch [16/100], Iter [960/3189] Loss: 0.2933 Acc: 87 %
# Epoch [16/100], Iter [970/3189] Loss: 0.2777 Acc: 87 %
# Epoch [16/100], Iter [980/3189] Loss: 0.2716 Acc: 87 %
# Epoch [16/100], Iter [990/3189] Loss: 0.2636 Acc: 87 %
# Epoch [16/100], Iter [1000/3189] Loss: 0.3034 Acc: 87 %
# Epoch [16/100], Iter [1010/3189] Loss: 0.2627 Acc: 87 %
# Epoch [16/100], Iter [1020/3189] Loss: 0.2878 Acc: 87 %
# Epoch [16/100], Iter [1030/3189] Loss: 0.2558 Acc: 87 %
# Epoch [16/100], Iter [1040/3189] Loss: 0.2862 Acc: 87 %
# Epoch [16/100], Iter [1050/3189] Loss: 0.2710 Acc: 87 %
# Epoch [16/100], Iter [1060/3189] Loss: 0.2865 Acc: 87 %
# Epoch [16/100], Iter [1070/3189] Loss: 0.2859 Acc: 87 %
# Epoch [16/100], Iter [1080/3189] Loss: 0.3217 Acc: 87 %
# Epoch [16/100], Iter [1090/3189] Loss: 0.2371 Acc: 87 %
# Epoch [16/100], Iter [1100/3189] Loss: 0.3011 Acc: 87 %
# Epoch [16/100], Iter [1110/3189] Loss: 0.3135 Acc: 87 %
# Epoch [16/100], Iter [1120/3189] Loss: 0.2999 Acc: 87 %
# Epoch [16/100], Iter [1130/3189] Loss: 0.2795 Acc: 87 %
# Epoch [16/100], Iter [1140/3189] Loss: 0.2715 Acc: 87 %
# Epoch [16/100], Iter [1150/3189] Loss: 0.2894 Acc: 87 %
# Epoch [16/100], Iter [1160/3189] Loss: 0.2926 Acc: 87 %
# Epoch [16/100], Iter [1170/3189] Loss: 0.3053 Acc: 87 %
# Epoch [16/100], Iter [1180/3189] Loss: 0.2969 Acc: 87 %
# Epoch [16/100], Iter [1190/3189] Loss: 0.3002 Acc: 87 %
# Epoch [16/100], Iter [1200/3189] Loss: 0.3185 Acc: 87 %
# Epoch [16/100], Iter [1210/3189] Loss: 0.2722 Acc: 87 %
# Epoch [16/100], Iter [1220/3189] Loss: 0.3085 Acc: 87 %
# Epoch [16/100], Iter [1230/3189] Loss: 0.2882 Acc: 87 %
# Epoch [16/100], Iter [1240/3189] Loss: 0.2730 Acc: 87 %
# Epoch [16/100], Iter [1250/3189] Loss: 0.2496 Acc: 87 %
# Epoch [16/100], Iter [1260/3189] Loss: 0.2789 Acc: 87 %
# Epoch [16/100], Iter [1270/3189] Loss: 0.3056 Acc: 87 %
# Epoch [16/100], Iter [1280/3189] Loss: 0.2877 Acc: 87 %
# Epoch [16/100], Iter [1290/3189] Loss: 0.3019 Acc: 87 %
# Epoch [16/100], Iter [1300/3189] Loss: 0.2990 Acc: 87 %
# Epoch [16/100], Iter [1310/3189] Loss: 0.2696 Acc: 87 %
# Epoch [16/100], Iter [1320/3189] Loss: 0.2655 Acc: 87 %
# Epoch [16/100], Iter [1330/3189] Loss: 0.2803 Acc: 87 %
# Epoch [16/100], Iter [1340/3189] Loss: 0.3019 Acc: 87 %
# Epoch [16/100], Iter [1350/3189] Loss: 0.2900 Acc: 87 %
# Epoch [16/100], Iter [1360/3189] Loss: 0.2879 Acc: 87 %
# Epoch [16/100], Iter [1370/3189] Loss: 0.3041 Acc: 87 %
# Epoch [16/100], Iter [1380/3189] Loss: 0.2635 Acc: 87 %
# Epoch [16/100], Iter [1390/3189] Loss: 0.3015 Acc: 87 %
# Epoch [16/100], Iter [1400/3189] Loss: 0.2892 Acc: 87 %
# Epoch [16/100], Iter [1410/3189] Loss: 0.2829 Acc: 87 %
# Epoch [16/100], Iter [1420/3189] Loss: 0.2646 Acc: 87 %
# Epoch [16/100], Iter [1430/3189] Loss: 0.2602 Acc: 87 %
# Epoch [16/100], Iter [1440/3189] Loss: 0.2831 Acc: 87 %
# Epoch [16/100], Iter [1450/3189] Loss: 0.2774 Acc: 87 %
# Epoch [16/100], Iter [1460/3189] Loss: 0.2962 Acc: 87 %
# Epoch [16/100], Iter [1470/3189] Loss: 0.2507 Acc: 87 %
# Epoch [16/100], Iter [1480/3189] Loss: 0.2860 Acc: 87 %
# Epoch [16/100], Iter [1490/3189] Loss: 0.2955 Acc: 87 %
# Epoch [16/100], Iter [1500/3189] Loss: 0.3137 Acc: 87 %
# Epoch [16/100], Iter [1510/3189] Loss: 0.2938 Acc: 87 %
# Epoch [16/100], Iter [1520/3189] Loss: 0.2883 Acc: 87 %
# Epoch [16/100], Iter [1530/3189] Loss: 0.2915 Acc: 87 %
# Epoch [16/100], Iter [1540/3189] Loss: 0.2645 Acc: 87 %
# Epoch [16/100], Iter [1550/3189] Loss: 0.3042 Acc: 87 %
# Epoch [16/100], Iter [1560/3189] Loss: 0.2758 Acc: 87 %
# Epoch [16/100], Iter [1570/3189] Loss: 0.2861 Acc: 87 %
# Epoch [16/100], Iter [1580/3189] Loss: 0.2843 Acc: 87 %
# Epoch [16/100], Iter [1590/3189] Loss: 0.2774 Acc: 87 %
# Epoch [16/100], Iter [1600/3189] Loss: 0.2839 Acc: 87 %
# Epoch [16/100], Iter [1610/3189] Loss: 0.3025 Acc: 87 %
# Epoch [16/100], Iter [1620/3189] Loss: 0.2623 Acc: 87 %
# Epoch [16/100], Iter [1630/3189] Loss: 0.2685 Acc: 87 %
# Epoch [16/100], Iter [1640/3189] Loss: 0.2611 Acc: 87 %
# Epoch [16/100], Iter [1650/3189] Loss: 0.2862 Acc: 87 %
# Epoch [16/100], Iter [1660/3189] Loss: 0.2811 Acc: 87 %
# Epoch [16/100], Iter [1670/3189] Loss: 0.2923 Acc: 87 %
# Epoch [16/100], Iter [1680/3189] Loss: 0.2741 Acc: 87 %
# Epoch [16/100], Iter [1690/3189] Loss: 0.3150 Acc: 87 %
# Epoch [16/100], Iter [1700/3189] Loss: 0.3022 Acc: 87 %
# Epoch [16/100], Iter [1710/3189] Loss: 0.2971 Acc: 87 %
# Epoch [16/100], Iter [1720/3189] Loss: 0.2873 Acc: 87 %
# Epoch [16/100], Iter [1730/3189] Loss: 0.2832 Acc: 87 %
# Epoch [16/100], Iter [1740/3189] Loss: 0.2760 Acc: 87 %
# Epoch [16/100], Iter [1750/3189] Loss: 0.2780 Acc: 87 %
# Epoch [16/100], Iter [1760/3189] Loss: 0.2758 Acc: 87 %
# Epoch [16/100], Iter [1770/3189] Loss: 0.2826 Acc: 87 %
# Epoch [16/100], Iter [1780/3189] Loss: 0.2904 Acc: 87 %
# Epoch [16/100], Iter [1790/3189] Loss: 0.2760 Acc: 87 %
# Epoch [16/100], Iter [1800/3189] Loss: 0.2793 Acc: 87 %
# Epoch [16/100], Iter [1810/3189] Loss: 0.2884 Acc: 87 %
# Epoch [16/100], Iter [1820/3189] Loss: 0.2854 Acc: 87 %
# Epoch [16/100], Iter [1830/3189] Loss: 0.2757 Acc: 87 %
# Epoch [16/100], Iter [1840/3189] Loss: 0.2689 Acc: 87 %
# Epoch [16/100], Iter [1850/3189] Loss: 0.2754 Acc: 87 %
# Epoch [16/100], Iter [1860/3189] Loss: 0.2719 Acc: 87 %
# Epoch [16/100], Iter [1870/3189] Loss: 0.2981 Acc: 87 %
# Epoch [16/100], Iter [1880/3189] Loss: 0.3224 Acc: 87 %
# Epoch [16/100], Iter [1890/3189] Loss: 0.2696 Acc: 87 %
# Epoch [16/100], Iter [1900/3189] Loss: 0.2947 Acc: 87 %
# Epoch [16/100], Iter [1910/3189] Loss: 0.2490 Acc: 87 %
# Epoch [16/100], Iter [1920/3189] Loss: 0.2744 Acc: 87 %
# Epoch [16/100], Iter [1930/3189] Loss: 0.2983 Acc: 87 %
# Epoch [16/100], Iter [1940/3189] Loss: 0.2738 Acc: 87 %
# Epoch [16/100], Iter [1950/3189] Loss: 0.2924 Acc: 87 %
# Epoch [16/100], Iter [1960/3189] Loss: 0.3110 Acc: 87 %
# Epoch [16/100], Iter [1970/3189] Loss: 0.2654 Acc: 87 %
# Epoch [16/100], Iter [1980/3189] Loss: 0.2796 Acc: 87 %
# Epoch [16/100], Iter [1990/3189] Loss: 0.2768 Acc: 87 %
# Epoch [16/100], Iter [2000/3189] Loss: 0.3147 Acc: 87 %
# Epoch [16/100], Iter [2010/3189] Loss: 0.2708 Acc: 87 %
# Epoch [16/100], Iter [2020/3189] Loss: 0.2925 Acc: 87 %
# Epoch [16/100], Iter [2030/3189] Loss: 0.2729 Acc: 87 %
# Epoch [16/100], Iter [2040/3189] Loss: 0.2933 Acc: 87 %
# Epoch [16/100], Iter [2050/3189] Loss: 0.2797 Acc: 87 %
# Epoch [16/100], Iter [2060/3189] Loss: 0.3023 Acc: 87 %
# Epoch [16/100], Iter [2070/3189] Loss: 0.2876 Acc: 87 %
# Epoch [16/100], Iter [2080/3189] Loss: 0.2703 Acc: 87 %
# Epoch [16/100], Iter [2090/3189] Loss: 0.2952 Acc: 87 %
# Epoch [16/100], Iter [2100/3189] Loss: 0.3014 Acc: 87 %
# Epoch [16/100], Iter [2110/3189] Loss: 0.2841 Acc: 87 %
# Epoch [16/100], Iter [2120/3189] Loss: 0.2868 Acc: 87 %
# Epoch [16/100], Iter [2130/3189] Loss: 0.2924 Acc: 87 %
# Epoch [16/100], Iter [2140/3189] Loss: 0.2842 Acc: 87 %
# Epoch [16/100], Iter [2150/3189] Loss: 0.2985 Acc: 87 %
# Epoch [16/100], Iter [2160/3189] Loss: 0.2682 Acc: 87 %
# Epoch [16/100], Iter [2170/3189] Loss: 0.3068 Acc: 87 %
# Epoch [16/100], Iter [2180/3189] Loss: 0.3031 Acc: 87 %
# Epoch [16/100], Iter [2190/3189] Loss: 0.2757 Acc: 87 %
# Epoch [16/100], Iter [2200/3189] Loss: 0.2761 Acc: 87 %
# Epoch [16/100], Iter [2210/3189] Loss: 0.2695 Acc: 87 %
# Epoch [16/100], Iter [2220/3189] Loss: 0.2858 Acc: 87 %
# Epoch [16/100], Iter [2230/3189] Loss: 0.3114 Acc: 87 %
# Epoch [16/100], Iter [2240/3189] Loss: 0.2689 Acc: 87 %
# Epoch [16/100], Iter [2250/3189] Loss: 0.2596 Acc: 87 %
# Epoch [16/100], Iter [2260/3189] Loss: 0.2690 Acc: 87 %
# Epoch [16/100], Iter [2270/3189] Loss: 0.2771 Acc: 87 %
# Epoch [16/100], Iter [2280/3189] Loss: 0.2779 Acc: 87 %
# Epoch [16/100], Iter [2290/3189] Loss: 0.2782 Acc: 87 %
# Epoch [16/100], Iter [2300/3189] Loss: 0.2890 Acc: 87 %
# Epoch [16/100], Iter [2310/3189] Loss: 0.2921 Acc: 87 %
# Epoch [16/100], Iter [2320/3189] Loss: 0.2731 Acc: 87 %
# Epoch [16/100], Iter [2330/3189] Loss: 0.3063 Acc: 87 %
# Epoch [16/100], Iter [2340/3189] Loss: 0.3005 Acc: 87 %
# Epoch [16/100], Iter [2350/3189] Loss: 0.2660 Acc: 87 %
# Epoch [16/100], Iter [2360/3189] Loss: 0.3116 Acc: 87 %
# Epoch [16/100], Iter [2370/3189] Loss: 0.2736 Acc: 87 %
# Epoch [16/100], Iter [2380/3189] Loss: 0.2670 Acc: 87 %
# Epoch [16/100], Iter [2390/3189] Loss: 0.2845 Acc: 87 %
# Epoch [16/100], Iter [2400/3189] Loss: 0.2686 Acc: 87 %
# Epoch [16/100], Iter [2410/3189] Loss: 0.2738 Acc: 87 %
# Epoch [16/100], Iter [2420/3189] Loss: 0.2924 Acc: 87 %
# Epoch [16/100], Iter [2430/3189] Loss: 0.2958 Acc: 87 %
# Epoch [16/100], Iter [2440/3189] Loss: 0.2887 Acc: 87 %
# Epoch [16/100], Iter [2450/3189] Loss: 0.2911 Acc: 87 %
# Epoch [16/100], Iter [2460/3189] Loss: 0.2583 Acc: 87 %
# Epoch [16/100], Iter [2470/3189] Loss: 0.2604 Acc: 87 %
# Epoch [16/100], Iter [2480/3189] Loss: 0.2799 Acc: 87 %
# Epoch [16/100], Iter [2490/3189] Loss: 0.2749 Acc: 87 %
# Epoch [16/100], Iter [2500/3189] Loss: 0.3184 Acc: 87 %
# Epoch [16/100], Iter [2510/3189] Loss: 0.2689 Acc: 87 %
# Epoch [16/100], Iter [2520/3189] Loss: 0.3084 Acc: 87 %
# Epoch [16/100], Iter [2530/3189] Loss: 0.3065 Acc: 87 %
# Epoch [16/100], Iter [2540/3189] Loss: 0.2787 Acc: 87 %
# Epoch [16/100], Iter [2550/3189] Loss: 0.3010 Acc: 87 %
# Epoch [16/100], Iter [2560/3189] Loss: 0.2846 Acc: 87 %
# Epoch [16/100], Iter [2570/3189] Loss: 0.2781 Acc: 87 %
# Epoch [16/100], Iter [2580/3189] Loss: 0.3086 Acc: 87 %
# Epoch [16/100], Iter [2590/3189] Loss: 0.2676 Acc: 87 %
# Epoch [16/100], Iter [2600/3189] Loss: 0.2792 Acc: 87 %
# Epoch [16/100], Iter [2610/3189] Loss: 0.2895 Acc: 87 %
# Epoch [16/100], Iter [2620/3189] Loss: 0.2482 Acc: 87 %
# Epoch [16/100], Iter [2630/3189] Loss: 0.3050 Acc: 87 %
# Epoch [16/100], Iter [2640/3189] Loss: 0.2767 Acc: 87 %
# Epoch [16/100], Iter [2650/3189] Loss: 0.2804 Acc: 87 %
# Epoch [16/100], Iter [2660/3189] Loss: 0.2851 Acc: 87 %
# Epoch [16/100], Iter [2670/3189] Loss: 0.2959 Acc: 87 %
# Epoch [16/100], Iter [2680/3189] Loss: 0.3058 Acc: 87 %
# Epoch [16/100], Iter [2690/3189] Loss: 0.2817 Acc: 87 %
# Epoch [16/100], Iter [2700/3189] Loss: 0.2798 Acc: 87 %
# Epoch [16/100], Iter [2710/3189] Loss: 0.2906 Acc: 87 %
# Epoch [16/100], Iter [2720/3189] Loss: 0.2842 Acc: 87 %
# Epoch [16/100], Iter [2730/3189] Loss: 0.2739 Acc: 87 %
# Epoch [16/100], Iter [2740/3189] Loss: 0.2749 Acc: 87 %
# Epoch [16/100], Iter [2750/3189] Loss: 0.2832 Acc: 87 %
# Epoch [16/100], Iter [2760/3189] Loss: 0.3085 Acc: 87 %
# Epoch [16/100], Iter [2770/3189] Loss: 0.2769 Acc: 87 %
# Epoch [16/100], Iter [2780/3189] Loss: 0.3128 Acc: 87 %
# Epoch [16/100], Iter [2790/3189] Loss: 0.2860 Acc: 87 %
# Epoch [16/100], Iter [2800/3189] Loss: 0.3072 Acc: 87 %
# Epoch [16/100], Iter [2810/3189] Loss: 0.2991 Acc: 87 %
# Epoch [16/100], Iter [2820/3189] Loss: 0.2832 Acc: 87 %
# Epoch [16/100], Iter [2830/3189] Loss: 0.3083 Acc: 87 %
# Epoch [16/100], Iter [2840/3189] Loss: 0.2784 Acc: 87 %
# Epoch [16/100], Iter [2850/3189] Loss: 0.2818 Acc: 87 %
# Epoch [16/100], Iter [2860/3189] Loss: 0.2951 Acc: 87 %
# Epoch [16/100], Iter [2870/3189] Loss: 0.2781 Acc: 87 %
# Epoch [16/100], Iter [2880/3189] Loss: 0.2619 Acc: 87 %
# Epoch [16/100], Iter [2890/3189] Loss: 0.2915 Acc: 87 %
# Epoch [16/100], Iter [2900/3189] Loss: 0.2855 Acc: 87 %
# Epoch [16/100], Iter [2910/3189] Loss: 0.3134 Acc: 87 %
# Epoch [16/100], Iter [2920/3189] Loss: 0.2628 Acc: 87 %
# Epoch [16/100], Iter [2930/3189] Loss: 0.2644 Acc: 87 %
# Epoch [16/100], Iter [2940/3189] Loss: 0.2904 Acc: 87 %
# Epoch [16/100], Iter [2950/3189] Loss: 0.2947 Acc: 87 %
# Epoch [16/100], Iter [2960/3189] Loss: 0.3123 Acc: 87 %
# Epoch [16/100], Iter [2970/3189] Loss: 0.2636 Acc: 87 %
# Epoch [16/100], Iter [2980/3189] Loss: 0.2880 Acc: 87 %
# Epoch [16/100], Iter [2990/3189] Loss: 0.2685 Acc: 87 %
# Epoch [16/100], Iter [3000/3189] Loss: 0.2566 Acc: 87 %
# Epoch [16/100], Iter [3010/3189] Loss: 0.3111 Acc: 87 %
# Epoch [16/100], Iter [3020/3189] Loss: 0.2615 Acc: 87 %
# Epoch [16/100], Iter [3030/3189] Loss: 0.3183 Acc: 87 %
# Epoch [16/100], Iter [3040/3189] Loss: 0.2832 Acc: 87 %
# Epoch [16/100], Iter [3050/3189] Loss: 0.2591 Acc: 87 %
# Epoch [16/100], Iter [3060/3189] Loss: 0.3084 Acc: 87 %
# Epoch [16/100], Iter [3070/3189] Loss: 0.2677 Acc: 87 %
# Epoch [16/100], Iter [3080/3189] Loss: 0.2713 Acc: 87 %
# Epoch [16/100], Iter [3090/3189] Loss: 0.2816 Acc: 87 %
# Epoch [16/100], Iter [3100/3189] Loss: 0.2939 Acc: 87 %
# Epoch [16/100], Iter [3110/3189] Loss: 0.2628 Acc: 87 %
# Epoch [16/100], Iter [3120/3189] Loss: 0.2911 Acc: 87 %
# Epoch [16/100], Iter [3130/3189] Loss: 0.3191 Acc: 87 %
# Epoch [16/100], Iter [3140/3189] Loss: 0.2729 Acc: 87 %
# Epoch [16/100], Iter [3150/3189] Loss: 0.2454 Acc: 87 %
# Epoch [16/100], Iter [3160/3189] Loss: 0.2592 Acc: 87 %
# Epoch [16/100], Iter [3170/3189] Loss: 0.2854 Acc: 87 %
# Epoch [16/100], Iter [3180/3189] Loss: 0.2984 Acc: 87 %
# Accuracy of the model on the aki negative sequence: 75 %
# Accuracy of the model on the aki positive sequence: 99 %
# EarlyStopping counter: 10 out of 10
# Early stopping

# %%
rnn.load_state_dict(torch.load('/home/jiahao/code/SPH6004/mimiciv_aki/model/simple_lstm-7_max-acc.pt'))


from torch.autograd import Variable
criterion = nn.BCEWithLogitsLoss()
F = torch.nn.Sigmoid()
# model.eval()
correct = 0
total = 0
loss_sum_t = 0
nb_classes = 2
confusion_matrix = torch.zeros(nb_classes, nb_classes)
pred_y = list()
test_y = list()
probas_y = list()
probas_y2 = list()
rnn = rnn.cuda()
with torch.no_grad():
    rnn.eval()
    for x,y in test_loader:

        b_x = Variable(x.float().cuda())
        a = y
        b_y = Variable(y.view(-1,1).float().cuda())
        
        logits = rnn(b_x)
        results = F(logits)
        loss_test = criterion(logits, b_y)
        iter_loss_t = loss_test.data.item()
        loss_sum_t += float(iter_loss_t)
        outputs_m = 1-results
        outputs_f = torch.cat((outputs_m,results),1)
        probas_y.extend(outputs_f.data.cpu().numpy().tolist())
        probas_y2.extend(results.data.cpu().numpy().tolist())
       
        test_y.extend(a.data.cpu().numpy().flatten().tolist())
        predicted = (results.data>0.5).float()
        pred_y.extend(predicted.data.cpu().numpy().flatten().tolist())
        
        for t, p in zip(b_y.view(-1), predicted.view(-1)):
            confusion_matrix[t.long(), p.long()] += 1
    acc = confusion_matrix.diag() / confusion_matrix.sum(1)
    acc_non = acc[0]
    acc_in = acc[1]
    mean_acc = torch.mean(acc)

# %%
import scikitplot as skplt
import numpy as np
import matplotlib.pyplot as plt
import sklearn
np_test = np.asarray(test_y)
np_pred = np.asarray(pred_y)
np_prob = np.asarray(probas_y)
np_prob_2 = np.asarray(probas_y2)
roc=skplt.metrics.plot_roc(np_test, np_prob,plot_micro=False,plot_macro=False,
                         text_fontsize ='large')

fpr_1, tpr_1, thresholds_1 =sklearn.metrics.roc_curve(np_test, np_prob_2)

# plt.savefig('roc_inception_1_1_early.png', dpi=300)
conf=skplt.metrics.plot_confusion_matrix(np_test, np_pred)
# plt.savefig('conf_inception_1_2_early.png', dpi=300)
sklearn.metrics.auc(fpr_1, tpr_1)
# Out:
# 0.91448441931212

# %%
def Find_Optimal_Cutoff(target, predicted):
    """ Find the optimal probability cutoff point for a classification model related to event rate
    Parameters
    ----------
    target : Matrix with dependent or target data, where rows are observations

    predicted : Matrix with predicted data, where rows are observations

    Returns
    -------     
    list type, with optimal cutoff value

    """
    fpr, tpr, threshold = roc_curve(target, predicted)
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'tf' : pd.Series(tpr-(1-fpr), index=i), 'threshold' : pd.Series(threshold, index=i)})
    roc_t = roc.iloc[(roc.tf-0).abs().argsort()[:1]]

    return list(roc_t['threshold'])

# %%
from sklearn.metrics import roc_curve, auc
import pandas as pd
threshold = Find_Optimal_Cutoff(test_y, probas_y2)
print(threshold)
# Out:
# [0.5346552133560181]
